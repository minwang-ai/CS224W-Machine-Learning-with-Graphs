# %% [markdown]
# # **CS224W - Colab 5**

# %% [markdown]
# In this final Colab we will continue experimenting with advanced topics in GNNs. Specifically, we will look at different techniques for scaling up GNNs using PyTorch Geometric, DeepSNAP and NetworkX. In the preivous Colab we worked with PyTorch Geometric's `NeighborSampler` to scale up training and testing on the OGB `arxiv` dataset and now we will be using DeepSNAP and NetworkX, to **implement our own simplified version** of `NeighborSampler` and run experiments with different sampling ratios on the Cora graph.
#
# Lastly, we will partition the Cora graph into clusters by using different partition algorithms and then train the models using a vanilla **Cluster-GCN**.
#
# **Note**: Make sure to **sequentially run all the cells in each section**, so that the intermediate variables / packages will carry over to the next cell

# %% [markdown]
# # Device
# You likely will want to us a GPU for this Colab.
#
# Please click `Runtime` and then `Change runtime type`. Then set the `hardware accelerator` to **GPU**.

# %% [markdown]
# # Installation

# %%
# Install torch geometric
import os
if 'IS_GRADESCOPE_ENV' not in os.environ:
  # !pip install torch-scatter -f https://pytorch-geometric.com/whl/torch-1.12.0+cu113.html
  # !pip install torch-sparse -f https://pytorch-geometric.com/whl/torch-1.12.0+cu113.html
  # !pip install torch-geometric
  # !pip install -q ogb
  # !pip install -q git+https://github.com/snap-stanford/deepsnap.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://pytorch-geometric.com/whl/torch-1.12.0+cu113.html
# Collecting torch-scatter
#   Downloading https://data.pyg.org/whl/torch-1.12.0%2Bcu113/torch_scatter-2.0.9-cp37-cp37m-linux_x86_64.whl (7.9 MB)
#      |████████████████████████████████| 7.9 MB 47.7 MB/s
# Installing collected packages: torch-scatter
# Successfully installed torch-scatter-2.0.9
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://pytorch-geometric.com/whl/torch-1.12.0+cu113.html
# Collecting torch-sparse
#   Downloading https://data.pyg.org/whl/torch-1.12.0%2Bcu113/torch_sparse-0.6.14-cp37-cp37m-linux_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 52.8 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-sparse) (1.7.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from scipy->torch-sparse) (1.21.6)
# Installing collected packages: torch-sparse
# Successfully installed torch-sparse-0.6.14
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch-geometric
#   Downloading torch_geometric-2.0.4.tar.gz (407 kB)
#      |████████████████████████████████| 407 kB 17.6 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (4.64.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.23.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (3.0.9)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.0.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->torch-geometric) (2.0.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (3.0.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (3.1.0)
# Building wheels for collected packages: torch-geometric
#   Building wheel for torch-geometric (setup.py) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-2.0.4-py3-none-any.whl size=616603 sha256=3e74db4dbef3325f4d4660982f769a8154a7c0509eb98265575cb991a2377dff
#   Stored in directory: /root/.cache/pip/wheels/18/a6/a4/ca18c3051fcead866fe7b85700ee2240d883562a1bc70ce421
# Successfully built torch-geometric
# Installing collected packages: torch-geometric
# Successfully installed torch-geometric-2.0.4
#      |████████████████████████████████| 78 kB 3.8 MB/s
#   Building wheel for littleutils (setup.py) ... done
#   Building wheel for deepsnap (setup.py) ... done

# %%
import torch_geometric
torch_geometric.__version__
# Out:
# '2.0.4'

# %% [markdown]
# # 1) Neighbor Sampling with Different Ratios
#
# We will implement our own simplified version of Neighbor Sampling using DeepSNAP and NetworkX. Then we will use our sampler to train models with **different neighborhood sampling ratios** and compare their performance.
#
# To make our experiments faster, we will use the Cora graph.

# %% [markdown]
# ## Setup

# %%
import copy
import torch
import random
import numpy as np
import pandas as pd
import networkx as nx
import torch.nn as nn
import torch.nn.functional as F

from torch_geometric.nn import SAGEConv
from torch.utils.data import DataLoader
from torch_geometric.datasets import Planetoid
from torch.nn import Sequential, Linear, ReLU
from deepsnap.dataset import GraphDataset
from deepsnap.graph import Graph

if 'IS_GRADESCOPE_ENV' not in os.environ:
  pyg_dataset = Planetoid('./tmp', "Cora")
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Processing...
# Done!

# %% [markdown]
# ## GNN Model
#
# We use a simple GraphSage GNN model, which we provide to you below. Similar to in section one, notice the slightly **different implementations of the forward method** depending on the data `mode`. When `mode = "batch"` we use Neighbor sampling. Thus, the data parameter contains our graph's node features (`x`) and a list `edge_indices` containing the connectivity of each GNN layer (i.e. an edge_index for each layer, defining the **bipartite** neighborhood computation graph).
#
# **NOTE:** Refer to sections *Neighbor Sampling* and *PyTorch Geometric Neighbor Sampler* from Colab4 for a detailed overview of the Neighbor Sampling technique.

# %%
class GNN(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, args):
        super(GNN, self).__init__()
        self.dropout = args['dropout']
        self.num_layers = args['num_layers']

        self.convs = nn.ModuleList()
        self.bns = nn.ModuleList()

        self.convs.append(SAGEConv(input_dim, hidden_dim))
        self.bns.append(nn.BatchNorm1d(hidden_dim))

        for l in range(self.num_layers - 2):
            self.convs.append(SAGEConv(hidden_dim, hidden_dim))
            self.bns.append(nn.BatchNorm1d(hidden_dim))
        self.convs.append(SAGEConv(hidden_dim, hidden_dim))

        self.post_mp = nn.Linear(hidden_dim, output_dim)

    def forward(self, data, mode="batch"):
        # Observe the difference between mode == "batch" and mode == "all".
        # In mode == "batch" we pass in an edge index for each conv layer
        # corresponding to that layer's bipartite graph structure.
        if mode == "batch":
            edge_indices, x = data
            for i in range(len(self.convs) - 1):
                edge_index = edge_indices[i]
                x = self.convs[i](x, edge_index)
                x = self.bns[i](x)
                x = F.relu(x)
                x = F.dropout(x, p=self.dropout, training=self.training)
            x = self.convs[-1](x, edge_indices[len(self.convs) - 1])
        else:
            x, edge_index = data.node_feature, data.edge_index
            for i in range(len(self.convs) - 1):
                x = self.convs[i](x, edge_index)
                x = self.bns[i](x)
                x = F.relu(x)
                x = F.dropout(x, p=self.dropout, training=self.training)
            x = self.convs[-1](x, edge_index)
        x = self.post_mp(x)
        x = F.log_softmax(x, dim=1)
        return x

# %% [markdown]
# ## Implementing Neighbor Sampling
#
# Now let's take a stab at implementing our own basic version of Neighbor Sampling using DeepSNAP and NetworkX. To decompose the process, we will define several helper functions before finally defining our own `neighbor_sampling` function!
#
# **NOTE:** Before working through this section, we highly recommend reviewing sections `Neighbor Sampling` and `PyTorch Geometric Neighbor Sampler`. Specifically, it is important to understand how we **explicitly define** an `edge_index` for each GNN layer, **representing the bipartite** computation graph connecting the `target_nodes` that we are embedding for that layer to their relevant neighbors from the previous layer needed for message passing.

# %% [markdown]
# ## **Question 1.1a**: Implementing the `sample_neighbors` function. (5 points)

# %%
def sample_neighbors(nodes, G, ratio, all_nodes):
    # TODO: Implement a function that takes as input a set of nodes(dst), 
    # a NetworkX graph G, and a neighbor sampling ratio and returns:
    #   1. A set of the sampled nodes (neighbors)
    #   2. A set union between `all_nodes` and the newly sampled neighbor nodes.
    #      This allows us to track the nodes needed across all message passing layers.
    #   3. The set of edges connecting the sampled neighboring nodes to our inpute
    #      set of nodes. Represents a bi-partite graph between targets (nodes)
    #      and source (neighbor) nodes.

    neighbors = set()
    edges = []

    ############# Your code here ############
    ## (~8-10 line of code)
    ## Note:
    ## 1. You will will need to sample neighbors from each node given to you in input
    ##    `nodes` list. 
    ##    Hint: Used graph `G` to assist in obtaining the neighbors of each node. 
    ## 2. Randomly sample neighbors without replacement (i.e. the same neighbors 
    ##    should not be selected more than once for a given node) 
    ## 3. The neighbors are stored in a set data structure to ensure that duplicates
    ##    are avoided.  This is useful as the set union will be taken with `all_nodes`. 
    ## 5. The edges list should contain all edges sampled in the form of a tuple
    ##    of (neighbor, node) 
    for node in nodes: 
      neighbors_n = set(G.neighbors(node)) #1. obtain the neighbors of each node n in set data structure
      num_sample = round(ratio*len(neighbors_n)) # the number of neighbors to sample
      neighbors_n = random.sample(neighbors_n, num_sample) # 2. Randomly sample neighbors without replacement
      neighbors = neighbors.union(neighbors_n) # store all the neighbors of each node in neighbors set
      for neighbor in neighbors_n:
        edges.append((neighbor, node))
    ########################################## 
    return neighbors, neighbors.union(all_nodes), edges
  
if 'IS_GRADESCOPE_ENV' not in os.environ:
  graphs_train, _, _ = \
      GraphDataset.pyg_to_graphs(pyg_dataset, verbose=True, fixed_split=True)

  graph_train = graphs_train[0]

  nodes = [15, 16, 17]
  neighbors_full, _, _ = sample_neighbors(nodes, graph_train.G, 1, set())
  neighbors_sampled, _, _ = sample_neighbors(nodes, graph_train.G, 0.3, set())
  print ("Neighbors with ratio = 1:", neighbors_full)
  print ("Neighbors with ratio = 0.3:", neighbors_sampled)
  # Note that this is not expected to be 0.3. Since we apply
  # our sampling ratio for each node, the number of neighbors
  # for each node may not evenly divide by the ratio   
  print ("Ratio of sampled neighbors:", len(neighbors_sampled) / len(neighbors_full))
# Out:
# Index fields: train_mask ignored.
# Index fields: test_mask ignored.
# Index fields: val_mask ignored.
# Neighbors with ratio = 1: {1632, 1090, 1315, 1316, 1093, 970, 2444, 2642, 1271, 927, 24, 2140, 2367}
# Neighbors with ratio = 0.3: {1632, 24, 1090, 2140}
# Ratio of sampled neighbors: 0.3076923076923077

# %% [markdown]
# ## Tensor transformation and node relabeling helper functions.

# %%
def nodes_to_tensor(nodes):
    """
      Transforms a set of nodes into a node index tensor.
    """

    node_label_index = torch.tensor(list(nodes), dtype=torch.long)
    return node_label_index


def edges_to_tensor(edges):
    """
      Transforms a list of undirected edges into the corresponding PyG
      edge_index tensor representation. Notice that we explicitly make
      sure to include both edge directions.  
    """

    edge_index = torch.tensor(list(edges), dtype=torch.long)
    edge_index = torch.cat([edge_index, torch.flip(edge_index, [1])], dim=0)
    edge_index = edge_index.permute(1, 0)

    return edge_index

def relabel(nodes, labeled_nodes, edges_list):
    """
      Relabel nodes with 0 based indeces.
      
      During the sampling process, we are likely to sample a list of
      non-continuous node ids. However, our GNN models rely on continuous
      0 based indexing to index into the rows of our node features matrix 
      based on edges in the graph (edge_index)
    """

    relabeled_edges_list = []
    sorted_nodes = sorted(nodes)
    node_mapping = {node : i for i, node in enumerate(sorted_nodes)}
    print(node_mapping[0])
    for orig_edges in edges_list:
        relabeled_edges = []
        #print("edges_list",edges_list)
        for edge in orig_edges:
            #print("orig_edges",orig_edges)
            #print("edge",edge)
            #print("edge[0]",edge[0])
            #print("edge[1]",edge[1])
            relabeled_edges.append((node_mapping[edge[0]], node_mapping[edge[1]]))
        relabeled_edges_list.append(relabeled_edges)
    relabeled_labeled_nodes = [node_mapping[node] for node in labeled_nodes]
    relabeled_nodes = [node_mapping[node] for node in nodes]

    return relabeled_edges_list, relabeled_nodes, relabeled_labeled_nodes, sorted_nodes

# %% [markdown]
# ## **Question 1.1b**: Putting it all together - Implementing our own Neighbor Sampling function. (4 points)
#
# Now that we've developed a better understanding of what the Neighbor Sampling function does, we will implement our own version of it. Instead of choosing $H_k$ number of samples at each layer, we will use a **ratio** of the number of neigbors that a givn node has for each layer. Can you think of the pros and cons of using a ratio of the number of neighbors for a node at different layers?

# %%
def neighbor_sampling(graph, K=2, ratios=(0.1, 0.1, 0.1)):
    # TODO: Implement a function that performs Neighbor Sampling on an input
    # graph G for a K layer GNN. Notice that len(ratios) = K + 1. Ratios[-1]
    # determines size of our mini-batch (i.e. the number of labeled 
    # nodes we sample computation graphs for). 

    assert K + 1 == len(ratios)

    labeled_nodes = graph.node_label_index.tolist()
    random.shuffle(labeled_nodes)
    num = int(len(labeled_nodes) * ratios[-1]) # mini-batch size
    if num > 0:
        labeled_nodes = labeled_nodes[:num] # obtain mini-batch node
    nodes_list = [set(labeled_nodes)]
    edges_list = []
    all_nodes = labeled_nodes

    ############# Your code here ############
    ## (~4-6 line of code)
    ## Note:
    ## 1. Using your previously defined `sample_neighbors` function, build up the 
    ##    edges_list for our K layer network.
    ## 2. nodes_list is a list where nodes_list[i] is set of nodes used for message
    ##    passing in layer i+1 of our GNN (i.e. level i in our computation graph).
    ##    Notice, node_list[-1] represents the target nodes we want to 
    ##    embedd in the mini-batch.
    ## 3. edge_list is a list of the bi-partite edge conections where edge_list[i] 
    ##    is set of edges between layers in the computation graph.
    ## 4. all_nodes is used to track all the nodes needed for message passing.
    ## 5. Remember in a GNN, information flows from the base of the computation
    ##    graph to the root(base->root). How does this affect the way we add to the nodes_list 
    ##    and edge_list, as well as how we read from ratios (ratios[-1] 
    ##    represents the root nodes in our computation graph)?

    # sample base <- root
    for i in range(K-1, -1, -1): # k=3 layers range (2, 1, 0)
      neighbors, all_nodes, edges = sample_neighbors(nodes=nodes_list[-1], G=graph.G, ratio=ratios[i], all_nodes=all_nodes)
      nodes_list.append(neighbors)
      edges_list.append(edges)
    
    #5. Reverse the lists base -> root
    nodes_list.reverse()
    edges_list.reverse()

    #########################################

    relabeled_edges_list, relabeled_all_nodes, relabeled_labeled_nodes, sorted_original_nodes = \
        relabel(all_nodes, labeled_nodes, edges_list)

    node_index = nodes_to_tensor(sorted_original_nodes)
    # All node features that will be used
    node_feature = graph.node_feature[node_index]
    edge_indices = [edges_to_tensor(edges) for edges in relabeled_edges_list]
    node_label_index = nodes_to_tensor(relabeled_labeled_nodes)
    orig_node_label_index = nodes_to_tensor(labeled_nodes)
    log = "Sampled {} nodes, {} edges, {} labeled nodes"
    print(log.format(node_feature.shape[0], edge_indices[0].shape[1] // 2, node_label_index.shape[0]))
    return node_feature, edge_indices, node_label_index, orig_node_label_index

if 'IS_GRADESCOPE_ENV' not in os.environ:
  # Need to define some basic test! Primarily to test whether they build 
  # in the correct reverse order. So ideally something like ratio = (0.3, 0.5, 0.8).
  # Just need to check shapes.
  
  graphs_train, _, _ = \
      GraphDataset.pyg_to_graphs(pyg_dataset, verbose=True, fixed_split=True)

  graph_train = graphs_train[0]

  node_feature, edge_indices, node_label_index, _ = neighbor_sampling(graph_train, K=3, ratios=(1, 1, 1, 1))
# Out:
# Index fields: train_mask ignored.
# Index fields: test_mask ignored.
# Index fields: val_mask ignored.
# 0
# Sampled 2218 nodes, 7554 edges, 140 labeled nodes

# %% [markdown]
# ## Training and Testing
#
# Additionally, notice that node classification task on Cora is a semi-supervised classification task, here we keep all the labeled training nodes (140 nodes) by setting the last ratio to 1.

# %%
def train(train_graphs, val_graphs, args, model, optimizer, mode="batch"):
    best_val = 0
    best_model = None
    accs = []
    graph_train = train_graphs[0]
    graph_train.to(args['device'])
    for epoch in range(1, 1 + args['epochs']):
        model.train()
        optimizer.zero_grad()
        if mode == "batch":
            node_feature, edge_indices, node_label_index, orig_node_index = neighbor_sampling(graph_train, args['num_layers'], args['ratios'])
            node_feature = node_feature.to(args['device'])
            node_label_index = node_label_index.to(args['device'])
            for i in range(len(edge_indices)):
                edge_indices[i] = edge_indices[i].to(args['device'])
            pred = model([edge_indices, node_feature])
            pred = pred[node_label_index]
            label = graph_train.node_label[orig_node_index]
        elif mode == "community":
            graph = random.choice(train_graphs)
            graph = graph.to(args['device'])
            pred = model(graph, mode="all")
            pred = pred[graph.node_label_index]
            label = graph.node_label[graph.node_label_index]
        else:
            pred = model(graph_train, mode="all")
            label = graph_train.node_label
            pred = pred[graph_train.node_label_index]
        loss = F.nll_loss(pred, label)
        loss.backward()
        optimizer.step()

        train_acc, val_acc, test_acc = test(val_graphs, model)
        accs.append((train_acc, val_acc, test_acc))
        if val_acc > best_val:
            best_val = val_acc
            best_model = copy.deepcopy(model)
        print(f'Epoch: {epoch:02d}, '
              f'Loss: {loss:.4f}, '
              f'Train: {100 * train_acc:.2f}%, '
              f'Valid: {100 * val_acc:.2f}% '
              f'Test: {100 * test_acc:.2f}%')
    return best_model, accs

def test(graphs, model, save_model_results=False, batch_type="batch", title=None):
    model.eval()
    accs = []
  
    for graph in graphs:
        graph = graph.to(args['device'])
        pred = model(graph, mode="all")
        label = graph.node_label
        pred = pred[graph.node_label_index].max(1)[1]
        acc = pred.eq(label).sum().item()
        acc /= len(label)
        accs.append(acc)
    
    if save_model_results:
      print ("Saving Model Predictions for Model:", batch_type, title)

      data = {}
      # The last dataset we test is the test graph
      data['pred'] = pred.view(-1).cpu().detach().numpy()
      data['label'] = label.view(-1).cpu().detach().numpy()

      df = pd.DataFrame(data=data)
      # Save locally as csv
      file_name = 'CORA_Node_' + batch_type
      if title is not None:
        file_name = file_name + "_" + title

      df.to_csv(file_name + '.csv', sep=',', index=False)

    return accs

# %%
args = {
    'device': torch.device('cuda' if torch.cuda.is_available() else 'cpu'),
    'dropout': 0.5,
    'num_layers': 2,
    'hidden_size': 64,
    'lr': 0.005,
    'epochs': 50,
    'ratios': (0.8, 0.8, 1),
}

# %%
def set_seed(seed=224):

    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.backends.cudnn.benchmark = False

# %% [markdown]
# ## Full-Batch Training
#
# As a baseline, we train our GNN model over the entire graph without any Neighbor Sampling.

# %%
if 'IS_GRADESCOPE_ENV' not in os.environ:
  
  set_seed()

  graphs_train, graphs_val, graphs_test = \
      GraphDataset.pyg_to_graphs(pyg_dataset, verbose=True, fixed_split=True)

  graph_train = graphs_train[0]
  graph_val = graphs_val[0]
  graph_test = graphs_test[0]

  model = GNN(graph_train.num_node_features, args['hidden_size'], graph_train.num_node_labels, args).to(args['device'])
  optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'])
  graphs = [graph_train, graph_val, graph_test]
  all_best_model, all_accs = train(graphs, graphs, args, model, optimizer, mode="all")
  train_acc, val_acc, test_acc = test([graph_train, graph_val, graph_test], all_best_model)
  print('Best model:',
        f'Train: {100 * train_acc:.2f}%, '
        f'Valid: {100 * val_acc:.2f}% '
        f'Test: {100 * test_acc:.2f}%')
# Out:
# Index fields: train_mask ignored.
# Index fields: test_mask ignored.
# Index fields: val_mask ignored.
# Epoch: 01, Loss: 2.0228, Train: 65.00%, Valid: 29.20% Test: 35.20%
# Epoch: 02, Loss: 1.0957, Train: 98.57%, Valid: 54.20% Test: 58.60%
# Epoch: 03, Loss: 0.6141, Train: 100.00%, Valid: 68.60% Test: 70.20%
# Epoch: 04, Loss: 0.2814, Train: 100.00%, Valid: 74.60% Test: 73.80%
# Epoch: 05, Loss: 0.1553, Train: 100.00%, Valid: 75.60% Test: 75.50%
# Epoch: 06, Loss: 0.0629, Train: 100.00%, Valid: 76.40% Test: 76.10%
# Epoch: 07, Loss: 0.0454, Train: 100.00%, Valid: 76.80% Test: 76.00%
# Epoch: 08, Loss: 0.0232, Train: 100.00%, Valid: 77.20% Test: 76.70%
# Epoch: 09, Loss: 0.0108, Train: 100.00%, Valid: 77.20% Test: 76.20%
# Epoch: 10, Loss: 0.0120, Train: 100.00%, Valid: 77.20% Test: 76.00%
# Epoch: 11, Loss: 0.0047, Train: 100.00%, Valid: 76.60% Test: 76.00%
# Epoch: 12, Loss: 0.0061, Train: 100.00%, Valid: 76.60% Test: 76.10%
# Epoch: 13, Loss: 0.0046, Train: 100.00%, Valid: 76.20% Test: 76.00%
# Epoch: 14, Loss: 0.0012, Train: 100.00%, Valid: 75.80% Test: 76.00%
# Epoch: 15, Loss: 0.0049, Train: 100.00%, Valid: 75.80% Test: 75.80%
# Epoch: 16, Loss: 0.0019, Train: 100.00%, Valid: 75.40% Test: 75.70%
# Epoch: 17, Loss: 0.0006, Train: 100.00%, Valid: 75.20% Test: 75.80%
# Epoch: 18, Loss: 0.0013, Train: 100.00%, Valid: 75.20% Test: 75.70%
# Epoch: 19, Loss: 0.0003, Train: 100.00%, Valid: 75.00% Test: 75.70%
# Epoch: 20, Loss: 0.0005, Train: 100.00%, Valid: 75.00% Test: 75.60%
# Epoch: 21, Loss: 0.0003, Train: 100.00%, Valid: 75.20% Test: 75.40%
# Epoch: 22, Loss: 0.0001, Train: 100.00%, Valid: 75.20% Test: 75.30%
# Epoch: 23, Loss: 0.0005, Train: 100.00%, Valid: 75.00% Test: 75.20%
# Epoch: 24, Loss: 0.0004, Train: 100.00%, Valid: 74.80% Test: 75.20%
# Epoch: 25, Loss: 0.0001, Train: 100.00%, Valid: 74.80% Test: 75.10%
# Epoch: 26, Loss: 0.0002, Train: 100.00%, Valid: 74.40% Test: 75.00%
# Epoch: 27, Loss: 0.0005, Train: 100.00%, Valid: 74.80% Test: 75.10%
# Epoch: 28, Loss: 0.0002, Train: 100.00%, Valid: 74.80% Test: 75.10%
# Epoch: 29, Loss: 0.0007, Train: 100.00%, Valid: 74.80% Test: 75.20%
# Epoch: 30, Loss: 0.0001, Train: 100.00%, Valid: 74.80% Test: 75.10%
# Epoch: 31, Loss: 0.0007, Train: 100.00%, Valid: 75.00% Test: 75.10%
# Epoch: 32, Loss: 0.0000, Train: 100.00%, Valid: 75.00% Test: 75.00%
# Epoch: 33, Loss: 0.0001, Train: 100.00%, Valid: 75.00% Test: 75.20%
# Epoch: 34, Loss: 0.0000, Train: 100.00%, Valid: 75.00% Test: 75.20%
# Epoch: 35, Loss: 0.0001, Train: 100.00%, Valid: 75.00% Test: 75.20%
# Epoch: 36, Loss: 0.0000, Train: 100.00%, Valid: 74.80% Test: 75.20%
# Epoch: 37, Loss: 0.0000, Train: 100.00%, Valid: 74.60% Test: 75.40%
# Epoch: 38, Loss: 0.0000, Train: 100.00%, Valid: 74.60% Test: 75.40%
# Epoch: 39, Loss: 0.0001, Train: 100.00%, Valid: 74.60% Test: 75.40%
# Epoch: 40, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 75.40%
# Epoch: 41, Loss: 0.0002, Train: 100.00%, Valid: 74.20% Test: 75.10%
# Epoch: 42, Loss: 0.0002, Train: 100.00%, Valid: 74.40% Test: 75.00%
# Epoch: 43, Loss: 0.0000, Train: 100.00%, Valid: 74.60% Test: 75.00%
# Epoch: 44, Loss: 0.0000, Train: 100.00%, Valid: 74.60% Test: 75.00%
# Epoch: 45, Loss: 0.0001, Train: 100.00%, Valid: 74.60% Test: 74.90%
# Epoch: 46, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 74.80%
# Epoch: 47, Loss: 0.0001, Train: 100.00%, Valid: 74.40% Test: 74.80%
# Epoch: 48, Loss: 0.0007, Train: 100.00%, Valid: 74.40% Test: 74.90%
# Epoch: 49, Loss: 0.0001, Train: 100.00%, Valid: 74.40% Test: 74.90%
# Epoch: 50, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 74.90%
# Best model: Train: 100.00%, Valid: 77.20% Test: 76.70%

# %% [markdown]
# ## **Question 1.2a:** What is the maximum test accuracy using samping ratios = (0.7, 0.9, 1)? (12 points)
#
# Running the cell below will show the results of your best model and save your best model's predictions to a file named CORA_Node_batch_(0.7, 0.9, 1).csv'.
#
# As we have seen before you can view this file by clicking on the Folder icon on the left side pannel. When you sumbit your assignment, you will have to download this file and attatch it to your submission.

# %%
if 'IS_GRADESCOPE_ENV' not in os.environ:
  
  set_seed()

  args['ratios'] = (0.7, 0.9, 1)

  graphs_train, graphs_val, graphs_test = \
      GraphDataset.pyg_to_graphs(pyg_dataset, verbose=True, fixed_split=True)

  graph_train = graphs_train[0]
  graph_val = graphs_val[0]
  graph_test = graphs_test[0]

  model = GNN(graph_train.num_node_features, args['hidden_size'], graph_train.num_node_labels, args).to(args['device'])
  optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'])
  graphs = [graph_train, graph_val, graph_test]
  batch_best_model, batch_accs = train(graphs, graphs, args, model, optimizer)
  train_acc, val_acc, test_acc = test([graph_train, graph_val, graph_test], batch_best_model, save_model_results=True, batch_type="batch", title="(0.7,0.9,1)")
  print('Best model:',
        f'Train: {100 * train_acc:.2f}%, '
        f'Valid: {100 * val_acc:.2f}% '
        f'Test: {100 * test_acc:.2f}%')
# Out:
# Index fields: train_mask ignored.
# Index fields: test_mask ignored.
# Index fields: val_mask ignored.
# 0
# Sampled 1415 nodes, 2251 edges, 140 labeled nodes
# Epoch: 01, Loss: 2.0103, Train: 60.00%, Valid: 29.40% Test: 34.70%
# 0
# Sampled 1418 nodes, 2272 edges, 140 labeled nodes
# Epoch: 02, Loss: 1.2215, Train: 95.00%, Valid: 54.80% Test: 58.70%
# 0
# Sampled 1444 nodes, 2281 edges, 140 labeled nodes
# Epoch: 03, Loss: 0.7135, Train: 99.29%, Valid: 68.60% Test: 70.60%
# 0
# Sampled 1416 nodes, 2291 edges, 140 labeled nodes
# Epoch: 04, Loss: 0.4271, Train: 100.00%, Valid: 74.40% Test: 74.30%
# 0
# Sampled 1399 nodes, 2281 edges, 140 labeled nodes
# Epoch: 05, Loss: 0.2362, Train: 100.00%, Valid: 75.80% Test: 75.90%
# 0
# Sampled 1415 nodes, 2270 edges, 140 labeled nodes
# Epoch: 06, Loss: 0.1435, Train: 100.00%, Valid: 76.80% Test: 77.30%
# 0
# Sampled 1405 nodes, 2238 edges, 140 labeled nodes
# Epoch: 07, Loss: 0.0576, Train: 100.00%, Valid: 76.40% Test: 77.10%
# 0
# Sampled 1415 nodes, 2287 edges, 140 labeled nodes
# Epoch: 08, Loss: 0.0339, Train: 100.00%, Valid: 76.80% Test: 77.60%
# 0
# Sampled 1418 nodes, 2263 edges, 140 labeled nodes
# Epoch: 09, Loss: 0.0235, Train: 100.00%, Valid: 76.80% Test: 77.60%
# 0
# Sampled 1405 nodes, 2268 edges, 140 labeled nodes
# Epoch: 10, Loss: 0.0189, Train: 100.00%, Valid: 76.80% Test: 77.90%
# 0
# Sampled 1408 nodes, 2265 edges, 140 labeled nodes
# Epoch: 11, Loss: 0.0076, Train: 100.00%, Valid: 76.40% Test: 78.10%
# 0
# Sampled 1414 nodes, 2253 edges, 140 labeled nodes
# Epoch: 12, Loss: 0.0062, Train: 100.00%, Valid: 75.80% Test: 78.30%
# 0
# Sampled 1419 nodes, 2281 edges, 140 labeled nodes
# Epoch: 13, Loss: 0.0050, Train: 100.00%, Valid: 75.80% Test: 78.10%
# 0
# Sampled 1414 nodes, 2264 edges, 140 labeled nodes
# Epoch: 14, Loss: 0.0018, Train: 100.00%, Valid: 75.60% Test: 78.10%
# 0
# Sampled 1420 nodes, 2247 edges, 140 labeled nodes
# Epoch: 15, Loss: 0.0029, Train: 100.00%, Valid: 75.80% Test: 78.00%
# 0
# Sampled 1431 nodes, 2279 edges, 140 labeled nodes
# Epoch: 16, Loss: 0.0022, Train: 100.00%, Valid: 75.60% Test: 78.00%
# 0
# Sampled 1435 nodes, 2284 edges, 140 labeled nodes
# Epoch: 17, Loss: 0.0009, Train: 100.00%, Valid: 75.20% Test: 78.20%
# 0
# Sampled 1414 nodes, 2290 edges, 140 labeled nodes
# Epoch: 18, Loss: 0.0029, Train: 100.00%, Valid: 75.40% Test: 78.10%
# 0
# Sampled 1422 nodes, 2259 edges, 140 labeled nodes
# Epoch: 19, Loss: 0.0013, Train: 100.00%, Valid: 75.40% Test: 78.00%
# 0
# Sampled 1387 nodes, 2237 edges, 140 labeled nodes
# Epoch: 20, Loss: 0.0023, Train: 100.00%, Valid: 75.60% Test: 78.10%
# 0
# Sampled 1429 nodes, 2280 edges, 140 labeled nodes
# Epoch: 21, Loss: 0.0004, Train: 100.00%, Valid: 75.60% Test: 78.30%
# 0
# Sampled 1406 nodes, 2234 edges, 140 labeled nodes
# Epoch: 22, Loss: 0.0013, Train: 100.00%, Valid: 75.60% Test: 78.20%
# 0
# Sampled 1423 nodes, 2262 edges, 140 labeled nodes
# Epoch: 23, Loss: 0.0007, Train: 100.00%, Valid: 75.60% Test: 78.20%
# 0
# Sampled 1423 nodes, 2279 edges, 140 labeled nodes
# Epoch: 24, Loss: 0.0030, Train: 100.00%, Valid: 75.60% Test: 78.40%
# 0
# Sampled 1424 nodes, 2256 edges, 140 labeled nodes
# Epoch: 25, Loss: 0.0004, Train: 100.00%, Valid: 75.40% Test: 78.40%
# 0
# Sampled 1432 nodes, 2287 edges, 140 labeled nodes
# Epoch: 26, Loss: 0.0002, Train: 100.00%, Valid: 75.20% Test: 78.40%
# 0
# Sampled 1412 nodes, 2272 edges, 140 labeled nodes
# Epoch: 27, Loss: 0.0005, Train: 100.00%, Valid: 75.20% Test: 78.50%
# 0
# Sampled 1420 nodes, 2268 edges, 140 labeled nodes
# Epoch: 28, Loss: 0.0002, Train: 100.00%, Valid: 75.20% Test: 78.50%
# 0
# Sampled 1424 nodes, 2277 edges, 140 labeled nodes
# Epoch: 29, Loss: 0.0003, Train: 100.00%, Valid: 74.60% Test: 78.60%
# 0
# Sampled 1433 nodes, 2303 edges, 140 labeled nodes
# Epoch: 30, Loss: 0.0001, Train: 100.00%, Valid: 74.40% Test: 78.50%
# 0
# Sampled 1413 nodes, 2283 edges, 140 labeled nodes
# Epoch: 31, Loss: 0.0002, Train: 100.00%, Valid: 74.40% Test: 78.40%
# 0
# Sampled 1409 nodes, 2258 edges, 140 labeled nodes
# Epoch: 32, Loss: 0.0012, Train: 100.00%, Valid: 74.40% Test: 78.50%
# 0
# Sampled 1404 nodes, 2222 edges, 140 labeled nodes
# Epoch: 33, Loss: 0.0003, Train: 100.00%, Valid: 74.40% Test: 78.50%
# 0
# Sampled 1415 nodes, 2245 edges, 140 labeled nodes
# Epoch: 34, Loss: 0.0001, Train: 100.00%, Valid: 74.40% Test: 78.50%
# 0
# Sampled 1426 nodes, 2271 edges, 140 labeled nodes
# Epoch: 35, Loss: 0.0005, Train: 100.00%, Valid: 74.40% Test: 78.50%
# 0
# Sampled 1419 nodes, 2273 edges, 140 labeled nodes
# Epoch: 36, Loss: 0.0001, Train: 100.00%, Valid: 74.40% Test: 78.60%
# 0
# Sampled 1431 nodes, 2277 edges, 140 labeled nodes
# Epoch: 37, Loss: 0.0003, Train: 100.00%, Valid: 74.40% Test: 78.60%
# 0
# Sampled 1393 nodes, 2282 edges, 140 labeled nodes
# Epoch: 38, Loss: 0.0003, Train: 100.00%, Valid: 74.40% Test: 78.80%
# 0
# Sampled 1437 nodes, 2272 edges, 140 labeled nodes
# Epoch: 39, Loss: 0.0007, Train: 100.00%, Valid: 74.60% Test: 78.80%
# 0
# Sampled 1413 nodes, 2248 edges, 140 labeled nodes
# Epoch: 40, Loss: 0.0001, Train: 100.00%, Valid: 74.80% Test: 78.80%
# 0
# Sampled 1417 nodes, 2281 edges, 140 labeled nodes
# Epoch: 41, Loss: 0.0002, Train: 100.00%, Valid: 74.80% Test: 78.70%
# 0
# Sampled 1407 nodes, 2241 edges, 140 labeled nodes
# Epoch: 42, Loss: 0.0002, Train: 100.00%, Valid: 74.80% Test: 78.80%
# 0
# Sampled 1408 nodes, 2230 edges, 140 labeled nodes
# Epoch: 43, Loss: 0.0000, Train: 100.00%, Valid: 74.80% Test: 78.90%
# 0
# Sampled 1420 nodes, 2250 edges, 140 labeled nodes
# Epoch: 44, Loss: 0.0001, Train: 100.00%, Valid: 74.80% Test: 78.90%
# 0
# Sampled 1401 nodes, 2228 edges, 140 labeled nodes
# Epoch: 45, Loss: 0.0009, Train: 100.00%, Valid: 75.00% Test: 78.90%
# 0
# Sampled 1404 nodes, 2266 edges, 140 labeled nodes
# Epoch: 46, Loss: 0.0000, Train: 100.00%, Valid: 75.00% Test: 79.00%
# 0
# Sampled 1418 nodes, 2251 edges, 140 labeled nodes
# Epoch: 47, Loss: 0.0002, Train: 100.00%, Valid: 75.00% Test: 79.00%
# 0
# Sampled 1400 nodes, 2266 edges, 140 labeled nodes
# Epoch: 48, Loss: 0.0017, Train: 100.00%, Valid: 74.60% Test: 78.90%
# 0
# Sampled 1412 nodes, 2298 edges, 140 labeled nodes
# Epoch: 49, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 79.00%
# 0
# Sampled 1412 nodes, 2233 edges, 140 labeled nodes
# Epoch: 50, Loss: 0.0005, Train: 100.00%, Valid: 74.20% Test: 79.00%
# Saving Model Predictions for Model: batch (0.7,0.9,1)
# Best model: Train: 100.00%, Valid: 76.80% Test: 77.30%

# %% [markdown]
# ## **Question 1.2b:** What is the maximum test accuracy using samping ratios = (0.3, 0.5, 1)? (12 points)
#
# Running the cell below will show the results of your best model and save your best model's predictions to a file named CORA_Node_batch_(0.3, 0.5, 1).csv'.
#
# As we have seen before you can view this file by clicking on the Folder icon on the left side pannel. When you submit your assignment, you will have to download this file and attach it to your submission.

# %%
if 'IS_GRADESCOPE_ENV' not in os.environ:
  
  set_seed()

  # Change the ratio to 0.3
  args['ratios'] = (0.3, 0.5, 1)

  graphs_train, graphs_val, graphs_test = \
      GraphDataset.pyg_to_graphs(pyg_dataset, verbose=True, fixed_split=True)

  graph_train = graphs_train[0]
  graph_val = graphs_val[0]
  graph_test = graphs_test[0]

  model = GNN(graph_train.num_node_features, args['hidden_size'], graph_train.num_node_labels, args).to(args['device'])
  optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'])
  graphs = [graph_train, graph_val, graph_test]
  batch_best_model, batch_accs_1 = train(graphs, graphs, args, model, optimizer)
  train_acc, val_acc, test_acc = test([graph_train, graph_val, graph_test], batch_best_model, save_model_results=True, batch_type="batch", title="(0.3,0.5,1)")
  print('Best model:',
        f'Train: {100 * train_acc:.2f}%, '
        f'Valid: {100 * val_acc:.2f}% '
        f'Test: {100 * test_acc:.2f}%')
# Out:
# Index fields: train_mask ignored.
# Index fields: test_mask ignored.
# Index fields: val_mask ignored.
# 0
# Sampled 752 nodes, 648 edges, 140 labeled nodes
# Epoch: 01, Loss: 2.0302, Train: 45.71%, Valid: 18.80% Test: 24.60%
# 0
# Sampled 768 nodes, 659 edges, 140 labeled nodes
# Epoch: 02, Loss: 1.5105, Train: 88.57%, Valid: 41.80% Test: 47.30%
# 0
# Sampled 753 nodes, 646 edges, 140 labeled nodes
# Epoch: 03, Loss: 1.0645, Train: 96.43%, Valid: 58.40% Test: 61.10%
# 0
# Sampled 789 nodes, 652 edges, 140 labeled nodes
# Epoch: 04, Loss: 0.7891, Train: 97.86%, Valid: 63.00% Test: 66.20%
# 0
# Sampled 779 nodes, 666 edges, 140 labeled nodes
# Epoch: 05, Loss: 0.5718, Train: 98.57%, Valid: 67.80% Test: 69.40%
# 0
# Sampled 753 nodes, 625 edges, 140 labeled nodes
# Epoch: 06, Loss: 0.4101, Train: 99.29%, Valid: 69.80% Test: 71.60%
# 0
# Sampled 780 nodes, 643 edges, 140 labeled nodes
# Epoch: 07, Loss: 0.2713, Train: 99.29%, Valid: 71.40% Test: 72.10%
# 0
# Sampled 751 nodes, 647 edges, 140 labeled nodes
# Epoch: 08, Loss: 0.1592, Train: 100.00%, Valid: 73.20% Test: 73.30%
# 0
# Sampled 728 nodes, 629 edges, 140 labeled nodes
# Epoch: 09, Loss: 0.1513, Train: 100.00%, Valid: 74.40% Test: 73.70%
# 0
# Sampled 776 nodes, 662 edges, 140 labeled nodes
# Epoch: 10, Loss: 0.0949, Train: 100.00%, Valid: 74.80% Test: 74.30%
# 0
# Sampled 793 nodes, 661 edges, 140 labeled nodes
# Epoch: 11, Loss: 0.0772, Train: 100.00%, Valid: 74.80% Test: 74.90%
# 0
# Sampled 740 nodes, 629 edges, 140 labeled nodes
# Epoch: 12, Loss: 0.0582, Train: 100.00%, Valid: 74.80% Test: 74.70%
# 0
# Sampled 757 nodes, 641 edges, 140 labeled nodes
# Epoch: 13, Loss: 0.0559, Train: 100.00%, Valid: 74.60% Test: 75.00%
# 0
# Sampled 782 nodes, 653 edges, 140 labeled nodes
# Epoch: 14, Loss: 0.0258, Train: 100.00%, Valid: 75.00% Test: 75.10%
# 0
# Sampled 775 nodes, 663 edges, 140 labeled nodes
# Epoch: 15, Loss: 0.0359, Train: 100.00%, Valid: 75.40% Test: 75.20%
# 0
# Sampled 788 nodes, 666 edges, 140 labeled nodes
# Epoch: 16, Loss: 0.0308, Train: 100.00%, Valid: 75.40% Test: 75.10%
# 0
# Sampled 767 nodes, 669 edges, 140 labeled nodes
# Epoch: 17, Loss: 0.0096, Train: 100.00%, Valid: 75.60% Test: 75.10%
# 0
# Sampled 742 nodes, 634 edges, 140 labeled nodes
# Epoch: 18, Loss: 0.0111, Train: 100.00%, Valid: 75.40% Test: 75.50%
# 0
# Sampled 754 nodes, 642 edges, 140 labeled nodes
# Epoch: 19, Loss: 0.0076, Train: 100.00%, Valid: 75.60% Test: 75.70%
# 0
# Sampled 755 nodes, 660 edges, 140 labeled nodes
# Epoch: 20, Loss: 0.0112, Train: 100.00%, Valid: 75.40% Test: 75.60%
# 0
# Sampled 761 nodes, 655 edges, 140 labeled nodes
# Epoch: 21, Loss: 0.0073, Train: 100.00%, Valid: 75.60% Test: 75.40%
# 0
# Sampled 764 nodes, 655 edges, 140 labeled nodes
# Epoch: 22, Loss: 0.0087, Train: 100.00%, Valid: 75.60% Test: 75.50%
# 0
# Sampled 783 nodes, 651 edges, 140 labeled nodes
# Epoch: 23, Loss: 0.0100, Train: 100.00%, Valid: 75.60% Test: 75.50%
# 0
# Sampled 773 nodes, 665 edges, 140 labeled nodes
# Epoch: 24, Loss: 0.0037, Train: 100.00%, Valid: 75.40% Test: 75.40%
# 0
# Sampled 763 nodes, 649 edges, 140 labeled nodes
# Epoch: 25, Loss: 0.0031, Train: 100.00%, Valid: 75.40% Test: 75.40%
# 0
# Sampled 761 nodes, 640 edges, 140 labeled nodes
# Epoch: 26, Loss: 0.0010, Train: 100.00%, Valid: 75.40% Test: 75.50%
# 0
# Sampled 749 nodes, 648 edges, 140 labeled nodes
# Epoch: 27, Loss: 0.0065, Train: 100.00%, Valid: 75.40% Test: 75.60%
# 0
# Sampled 758 nodes, 639 edges, 140 labeled nodes
# Epoch: 28, Loss: 0.0049, Train: 100.00%, Valid: 75.40% Test: 75.70%
# 0
# Sampled 754 nodes, 633 edges, 140 labeled nodes
# Epoch: 29, Loss: 0.0026, Train: 100.00%, Valid: 75.40% Test: 75.70%
# 0
# Sampled 788 nodes, 675 edges, 140 labeled nodes
# Epoch: 30, Loss: 0.0041, Train: 100.00%, Valid: 75.00% Test: 75.60%
# 0
# Sampled 747 nodes, 646 edges, 140 labeled nodes
# Epoch: 31, Loss: 0.0160, Train: 100.00%, Valid: 75.00% Test: 75.60%
# 0
# Sampled 769 nodes, 659 edges, 140 labeled nodes
# Epoch: 32, Loss: 0.0027, Train: 100.00%, Valid: 75.00% Test: 75.50%
# 0
# Sampled 765 nodes, 643 edges, 140 labeled nodes
# Epoch: 33, Loss: 0.0023, Train: 100.00%, Valid: 74.80% Test: 75.10%
# 0
# Sampled 785 nodes, 649 edges, 140 labeled nodes
# Epoch: 34, Loss: 0.0010, Train: 100.00%, Valid: 74.60% Test: 75.30%
# 0
# Sampled 768 nodes, 645 edges, 140 labeled nodes
# Epoch: 35, Loss: 0.0004, Train: 100.00%, Valid: 74.40% Test: 75.30%
# 0
# Sampled 754 nodes, 665 edges, 140 labeled nodes
# Epoch: 36, Loss: 0.0017, Train: 100.00%, Valid: 74.60% Test: 75.20%
# 0
# Sampled 769 nodes, 655 edges, 140 labeled nodes
# Epoch: 37, Loss: 0.0010, Train: 100.00%, Valid: 74.60% Test: 75.10%
# 0
# Sampled 764 nodes, 645 edges, 140 labeled nodes
# Epoch: 38, Loss: 0.0035, Train: 100.00%, Valid: 74.60% Test: 75.30%
# 0
# Sampled 765 nodes, 675 edges, 140 labeled nodes
# Epoch: 39, Loss: 0.0005, Train: 100.00%, Valid: 74.40% Test: 75.20%
# 0
# Sampled 763 nodes, 643 edges, 140 labeled nodes
# Epoch: 40, Loss: 0.0012, Train: 100.00%, Valid: 74.40% Test: 75.40%
# 0
# Sampled 767 nodes, 656 edges, 140 labeled nodes
# Epoch: 41, Loss: 0.0019, Train: 100.00%, Valid: 74.40% Test: 75.40%
# 0
# Sampled 767 nodes, 662 edges, 140 labeled nodes
# Epoch: 42, Loss: 0.0022, Train: 100.00%, Valid: 74.60% Test: 75.80%
# 0
# Sampled 765 nodes, 638 edges, 140 labeled nodes
# Epoch: 43, Loss: 0.0005, Train: 100.00%, Valid: 74.80% Test: 75.80%
# 0
# Sampled 753 nodes, 663 edges, 140 labeled nodes
# Epoch: 44, Loss: 0.0007, Train: 100.00%, Valid: 74.80% Test: 75.50%
# 0
# Sampled 768 nodes, 669 edges, 140 labeled nodes
# Epoch: 45, Loss: 0.0008, Train: 100.00%, Valid: 74.80% Test: 75.60%
# 0
# Sampled 759 nodes, 649 edges, 140 labeled nodes
# Epoch: 46, Loss: 0.0005, Train: 100.00%, Valid: 74.80% Test: 75.50%
# 0
# Sampled 771 nodes, 681 edges, 140 labeled nodes
# Epoch: 47, Loss: 0.0063, Train: 100.00%, Valid: 74.60% Test: 75.50%
# 0
# Sampled 776 nodes, 642 edges, 140 labeled nodes
# Epoch: 48, Loss: 0.0007, Train: 100.00%, Valid: 74.40% Test: 75.40%
# 0
# Sampled 767 nodes, 644 edges, 140 labeled nodes
# Epoch: 49, Loss: 0.0005, Train: 100.00%, Valid: 74.60% Test: 75.30%
# 0
# Sampled 767 nodes, 636 edges, 140 labeled nodes
# Epoch: 50, Loss: 0.0038, Train: 100.00%, Valid: 74.80% Test: 75.20%
# Saving Model Predictions for Model: batch (0.3,0.5,1)
# Best model: Train: 100.00%, Valid: 75.60% Test: 75.10%

# %% [markdown]
# ## Visualization

# %%
import numpy as np
from matplotlib import pyplot as plt

if 'IS_GRADESCOPE_ENV' not in os.environ:
  batch_results = np.array(batch_accs)
  batch_results_1 = np.array(batch_accs_1)
  all_results = np.array(all_accs)

  x = np.arange(1, 51)

  plt.figure(figsize=(9, 7))

  plt.plot(x, batch_results[:, 0], label="Batch 0.8 Train")
  plt.plot(x, batch_results[:, 1], label="Batch 0.8 Validation")
  plt.plot(x, batch_results[:, 2], label="Batch 0.8 Test")
  plt.plot(x, batch_results_1[:, 0], label="Batch 0.3 Train")
  plt.plot(x, batch_results_1[:, 1], label="Batch 0.3 Validation")
  plt.plot(x, batch_results_1[:, 2], label="Batch 0.3 Test")
  plt.plot(x, all_results[:, 0], label="All Train")
  plt.plot(x, all_results[:, 1], label="All Validation")
  plt.plot(x, all_results[:, 2], label="All Test")
  plt.title('Model Accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

# %% [markdown]
# **NOTE:** We always **evaluate accuracy in full-batch** mode. Namely, **only during training** do we use **neighborhood sub-sampling**. We do this for a couple reason: 1) fairness of comparison, 2) we worry most about computational cost during training as compared to evaluation, and 3) during the inference phase we want to leverage as much neighborhood information as possible!

# %% [markdown]
# # 2) Cluster Sampling
#
# As discussed in Module 7.2, we can also use **subgraph (cluster) sampling** to scale up GNN. Specifically, we will explore the methods proposed in **Cluster-GCN** ([Chiang et al. (2019)](https://arxiv.org/abs/1905.07953)), where we **break** our graph into smaller subgraphs to avoid the computational cost of training on the entire graph at once.
#
# In this final section, we will implement a vanilla Cluster-GCN and experiment with 3 different community partition algorithms.
#
# **NOTE:** the code in this section requires that you have run the `Setup`, `GNN Model` and `Training and Testing` cells of section 2.

# %% [markdown]
# ## Setup

# %%
import copy
import torch
import random
import numpy as np
import networkx as nx
import torch.nn as nn
import pandas as pd
import torch.nn.functional as F
import community.community_louvain as community_louvain

from torch_geometric.nn import SAGEConv
from torch.utils.data import DataLoader
from torch_geometric.datasets import Planetoid
from torch.nn import Sequential, Linear, ReLU
from deepsnap.dataset import GraphDataset
from deepsnap.graph import Graph

if 'IS_GRADESCOPE_ENV' not in os.environ:   
  pyg_dataset = Planetoid('./tmp', "Cora")

# %%
args = {
    'device': torch.device('cuda' if torch.cuda.is_available() else 'cpu'),
    'dropout': 0.5,
    'num_layers': 2,
    'hidden_size': 64,
    'lr': 0.005,
    'epochs': 150,
}

# %% [markdown]
# ## Partitioning the Graph into Clusters
#
# We will experiment with three community detection / partition algorithms to partition our graph into different clusters:
# * [Kernighan–Lin algorithm (bisection)](https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.community.kernighan_lin.kernighan_lin_bisection.html)
# * [Clauset-Newman-Moore greedy modularity maximization](https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.community.modularity_max.greedy_modularity_communities.html#networkx.algorithms.community.modularity_max.greedy_modularity_communities)
# * [Louvain algorithm](https://python-louvain.readthedocs.io/en/latest/api.html)
#
#
# As a preprocessing step, we **partition** our graph into a list of seperate subgraphs using one of the three **communitiy detection algorithms** above. Then during training we iteratively train our vanilla Cluster-GNN model on a **randomly selected subgraph**, rather than on over the entire graph at once. To make training more **stable**, we **discard** any communities that have less than 10 nodes.
#
# Let's begin by defining the three partition algorithms.

# %%
def partition(G, method="louvain"):
    # TODO: Implement a function that takes a Networkx graph G and
    # partitions the graph into communities using the specified graph
    # partition algorithm.
    # 
    # Return: A list of sets of nodes, one for each community!

    communities = None

    if method == "louvain":
        ############# Your code here #############
        ## (~9 line of code)
        ## Note:
        ## 1. Find a community mapping corresponding to the partition of the 
        ##    graph nodes which maximizes the modularity for the Louvain algorithm. Returns:	partition:dictionnary
        ##    Set your resolution to 10 to discard any communities that have less than 10 nodes.
        ## 2. Create a mapping of communities to a set of member nodes. 
        ## 3. Extract the node sets from each community and return 
        ##    as a list of sets. 
        ##    Hint: Perhaps a dictionary structure can assist.
        ## 4. SET random_state = 8 

        # 1. return community mapping is a dict: key=node, value=community 4.
        node_community_mapping = community_louvain.best_partition(graph=G, partition=None, weight='weight', resolution=10, randomize=None, random_state=8)
        # 2. create a new mapping via a dict: key=community, value=a set of nodes
        community_node_mapping={}
        for node, community in node_community_mapping.items():
          if community in community_node_mapping.keys():# add nodes to a set
            community_node_mapping[community].add(node)
          else:# init set of nodes
            community_node_mapping[community] = set([node]) 
        # 3. 
        communities = list(community_node_mapping.values())

        ##########################################
    elif method == "bisection":
        ############# Your code here #############
        ## (~1 line of code)
        ## Note:
        ## 1. The Kernigan-Lin algorithm ensures that nodes are partitioned into two 
        ##    primary communities. Return: partition tuple
        ## 2. Ensure that the resultant data structure is consistent with expected
        ##    output.
        ## 3. SET seed = 8
        communities = list(nx.algorithms.community.kernighan_lin_bisection(G, partition=None, max_iter=10, weight='weight', seed=8))
        ##########################################
    elif method == "greedy":
        ############# Your code here #############
        ## (~1 line of code)
        ## Note:
        ## 1. Clauset-Newman-Moore greedy modularity maximization joins pair 
        ##    of communities nodes that most increases modularity until no such 
        ##    pair exists. Returns: communities: list
        communities = nx.algorithms.community.greedy_modularity_communities(G, weight=None, resolution=10)
        ##########################################

    return communities 


def preprocess(G, node_label_index, method="louvain"):
    graphs = []
    labeled_nodes = set(node_label_index.tolist())

    communities = partition(G, method)

    for community in communities:
        nodes = set(community)
        subgraph = G.subgraph(nodes)
        # Make sure each subgraph has more than 10 nodes
        if subgraph.number_of_nodes() > 10:
            node_mapping = {node : i for i, node in enumerate(subgraph.nodes())}
            subgraph = nx.relabel_nodes(subgraph, node_mapping)
            # Get the id of the training set labeled node in the new graph
            train_label_index = []
            for node in labeled_nodes:
                if node in node_mapping:
                    # Append relabeled labeled node index
                    train_label_index.append(node_mapping[node])

            # Make sure the subgraph contains at least one training set labeled node
            if len(train_label_index) > 0:
                dg = Graph(subgraph)
                # Update node_label_index
                dg.node_label_index = torch.tensor(train_label_index, dtype=torch.long)
                graphs.append(dg)
    return graphs

# %% [markdown]
# ## Experimenting with different graph partition algorithms
#
# We will now experiment with the three graph partition algorithms, using the resulting graph clusters to train our vanilla Cluster-GNN. We will first observe how each parition algorithm partitions the original graph. Then we will compare the perfomance of our vanilla **Cluster-GNN** trained using the** different graph clustering techniques**. Lastly, we will compare against training a vanilla GCN over the entire graph (refered to as **Full-Batch training**).

# %% [markdown]
# ## **Question 2.1a:** How does the Louvain algorithm partition our graph? (3 points)

# %%
if 'IS_GRADESCOPE_ENV' not in os.environ:
  
  set_seed()

  graphs_train, graphs_val, graphs_test = \
      GraphDataset.pyg_to_graphs(pyg_dataset, verbose=True, fixed_split=True)

  graph_train = graphs_train[0]
  graph_val = graphs_val[0]
  graph_test = graphs_test[0]
  graphs = preprocess(graph_train.G, graph_train.node_label_index, method="louvain")
  print()
  print("Partitioning the graph in to {} communities".format(len(graphs)))
  avg_num_nodes = 0
  avg_num_edges = 0
  for graph in graphs:
      avg_num_nodes += graph.num_nodes
      avg_num_edges += graph.num_edges
  avg_num_nodes = int(avg_num_nodes / len(graphs))
  avg_num_edges = int(avg_num_edges / len(graphs))
  print("Each community has {} nodes in average".format(avg_num_nodes))
  print("Each community has {} edges in average".format(avg_num_edges))
# Out:
# Index fields: train_mask ignored.
# Index fields: test_mask ignored.
# Index fields: val_mask ignored.
#
# Partitioning the graph in to 77 communities
# Each community has 21 nodes in average
# Each community has 30 edges in average

# %% [markdown]
# ## **Question 2.1b:** Using Louvain clustering, what is the maximum test accuracy obtained by your vanilla Cluster-GCN? (6 points)

# %%
if 'IS_GRADESCOPE_ENV' not in os.environ:
  
  set_seed()
  
  model = GNN(graph_train.num_node_features, args['hidden_size'], graph_train.num_node_labels, args).to(args['device'])
  optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'])
  louvain_best_model, louvain_accs = train(graphs, [graph_train, graph_val, graph_test], args, model, optimizer, mode="community")
  train_acc, val_acc, test_acc = test([graph_train, graph_val, graph_test], louvain_best_model, save_model_results=True, batch_type="cluster", title="louvain")
  print('Best model:',
        f'Train: {100 * train_acc:.2f}%, '
        f'Valid: {100 * val_acc:.2f}% '
        f'Test: {100 * test_acc:.2f}%')
# Out:
# Epoch: 01, Loss: 2.2475, Train: 13.57%, Valid: 7.20% Test: 9.00%
# Epoch: 02, Loss: 2.0039, Train: 20.71%, Valid: 8.60% Test: 11.40%
# Epoch: 03, Loss: 2.2459, Train: 18.57%, Valid: 13.00% Test: 13.60%
# Epoch: 04, Loss: 1.3824, Train: 16.43%, Valid: 13.60% Test: 13.80%
# Epoch: 05, Loss: 2.6401, Train: 18.57%, Valid: 15.00% Test: 14.60%
# Epoch: 06, Loss: 2.5787, Train: 20.71%, Valid: 15.40% Test: 16.60%
# Epoch: 07, Loss: 2.6248, Train: 21.43%, Valid: 16.60% Test: 18.20%
# Epoch: 08, Loss: 2.4910, Train: 22.86%, Valid: 16.80% Test: 18.70%
# Epoch: 09, Loss: 2.5500, Train: 23.57%, Valid: 17.20% Test: 19.20%
# Epoch: 10, Loss: 3.6896, Train: 22.14%, Valid: 18.40% Test: 21.20%
# Epoch: 11, Loss: 1.5465, Train: 23.57%, Valid: 16.60% Test: 21.50%
# Epoch: 12, Loss: 1.7542, Train: 24.29%, Valid: 15.00% Test: 18.00%
# Epoch: 13, Loss: 1.8731, Train: 22.86%, Valid: 13.60% Test: 14.50%
# Epoch: 14, Loss: 2.5883, Train: 22.86%, Valid: 10.80% Test: 11.30%
# Epoch: 15, Loss: 1.7295, Train: 22.14%, Valid: 9.60% Test: 9.30%
# Epoch: 16, Loss: 2.9222, Train: 22.14%, Valid: 10.80% Test: 9.10%
# Epoch: 17, Loss: 1.6310, Train: 22.14%, Valid: 11.60% Test: 9.80%
# Epoch: 18, Loss: 2.3224, Train: 22.86%, Valid: 11.80% Test: 9.40%
# Epoch: 19, Loss: 2.6001, Train: 23.57%, Valid: 11.00% Test: 9.00%
# Epoch: 20, Loss: 1.1372, Train: 23.57%, Valid: 13.20% Test: 9.40%
# Epoch: 21, Loss: 1.5426, Train: 26.43%, Valid: 12.00% Test: 8.90%
# Epoch: 22, Loss: 0.2949, Train: 22.86%, Valid: 10.60% Test: 9.00%
# Epoch: 23, Loss: 1.7837, Train: 21.43%, Valid: 10.40% Test: 9.00%
# Epoch: 24, Loss: 3.3548, Train: 23.57%, Valid: 10.20% Test: 9.30%
# Epoch: 25, Loss: 1.4559, Train: 22.14%, Valid: 9.60% Test: 10.00%
# Epoch: 26, Loss: 1.0774, Train: 25.00%, Valid: 10.40% Test: 10.00%
# Epoch: 27, Loss: 3.0715, Train: 25.71%, Valid: 11.80% Test: 10.60%
# Epoch: 28, Loss: 0.3368, Train: 27.14%, Valid: 11.60% Test: 12.10%
# Epoch: 29, Loss: 1.5439, Train: 26.43%, Valid: 11.20% Test: 12.50%
# Epoch: 30, Loss: 1.7088, Train: 28.57%, Valid: 11.00% Test: 11.90%
# Epoch: 31, Loss: 3.3427, Train: 25.00%, Valid: 11.20% Test: 11.60%
# Epoch: 32, Loss: 0.7771, Train: 25.71%, Valid: 10.60% Test: 11.00%
# Epoch: 33, Loss: 1.8770, Train: 25.00%, Valid: 11.60% Test: 11.50%
# Epoch: 34, Loss: 2.6074, Train: 25.00%, Valid: 11.20% Test: 10.90%
# Epoch: 35, Loss: 1.9601, Train: 25.71%, Valid: 11.00% Test: 9.60%
# Epoch: 36, Loss: 0.9160, Train: 22.86%, Valid: 10.80% Test: 9.10%
# Epoch: 37, Loss: 2.8357, Train: 25.71%, Valid: 11.00% Test: 9.70%
# Epoch: 38, Loss: 0.5760, Train: 24.29%, Valid: 11.00% Test: 8.70%
# Epoch: 39, Loss: 2.1262, Train: 24.29%, Valid: 10.80% Test: 9.30%
# Epoch: 40, Loss: 1.3920, Train: 24.29%, Valid: 10.60% Test: 9.90%
# Epoch: 41, Loss: 3.5451, Train: 23.57%, Valid: 11.40% Test: 11.10%
# Epoch: 42, Loss: 3.3492, Train: 21.43%, Valid: 11.40% Test: 12.60%
# Epoch: 43, Loss: 3.0640, Train: 21.43%, Valid: 12.80% Test: 13.30%
# Epoch: 44, Loss: 2.7309, Train: 26.43%, Valid: 12.40% Test: 14.10%
# Epoch: 45, Loss: 0.9440, Train: 27.86%, Valid: 12.80% Test: 14.90%
# Epoch: 46, Loss: 1.6209, Train: 30.71%, Valid: 14.60% Test: 15.60%
# Epoch: 47, Loss: 4.7187, Train: 37.14%, Valid: 15.00% Test: 16.40%
# Epoch: 48, Loss: 0.4061, Train: 39.29%, Valid: 14.80% Test: 17.10%
# Epoch: 49, Loss: 0.2443, Train: 38.57%, Valid: 15.60% Test: 16.70%
# Epoch: 50, Loss: 0.3152, Train: 40.00%, Valid: 14.20% Test: 16.30%
# Epoch: 51, Loss: 0.0638, Train: 40.71%, Valid: 13.00% Test: 14.90%
# Epoch: 52, Loss: 1.0026, Train: 39.29%, Valid: 11.60% Test: 13.90%
# Epoch: 53, Loss: 0.5037, Train: 37.14%, Valid: 11.20% Test: 13.40%
# Epoch: 54, Loss: 0.0866, Train: 37.14%, Valid: 11.00% Test: 12.20%
# Epoch: 55, Loss: 0.3910, Train: 35.71%, Valid: 9.60% Test: 11.10%
# Epoch: 56, Loss: 1.1625, Train: 35.00%, Valid: 10.20% Test: 10.60%
# Epoch: 57, Loss: 1.4963, Train: 34.29%, Valid: 9.20% Test: 10.00%
# Epoch: 58, Loss: 0.1311, Train: 35.71%, Valid: 9.60% Test: 10.00%
# Epoch: 59, Loss: 3.6724, Train: 36.43%, Valid: 9.60% Test: 9.90%
# Epoch: 60, Loss: 2.4130, Train: 37.86%, Valid: 10.40% Test: 10.40%
# Epoch: 61, Loss: 1.0969, Train: 36.43%, Valid: 11.40% Test: 11.30%
# Epoch: 62, Loss: 1.5137, Train: 37.86%, Valid: 10.80% Test: 11.50%
# Epoch: 63, Loss: 2.4103, Train: 38.57%, Valid: 11.00% Test: 11.80%
# Epoch: 64, Loss: 1.0314, Train: 39.29%, Valid: 10.80% Test: 11.60%
# Epoch: 65, Loss: 1.5490, Train: 38.57%, Valid: 11.40% Test: 11.90%
# Epoch: 66, Loss: 0.3869, Train: 40.00%, Valid: 12.00% Test: 12.50%
# Epoch: 67, Loss: 4.7156, Train: 40.71%, Valid: 12.40% Test: 12.30%
# Epoch: 68, Loss: 0.5351, Train: 40.71%, Valid: 12.60% Test: 13.30%
# Epoch: 69, Loss: 1.0651, Train: 40.71%, Valid: 12.00% Test: 14.10%
# Epoch: 70, Loss: 3.0398, Train: 42.14%, Valid: 13.40% Test: 16.00%
# Epoch: 71, Loss: 3.4672, Train: 42.86%, Valid: 14.80% Test: 17.70%
# Epoch: 72, Loss: 1.0583, Train: 45.00%, Valid: 15.20% Test: 18.10%
# Epoch: 73, Loss: 0.9642, Train: 45.00%, Valid: 16.00% Test: 18.70%
# Epoch: 74, Loss: 0.0259, Train: 43.57%, Valid: 15.80% Test: 19.00%
# Epoch: 75, Loss: 2.1023, Train: 43.57%, Valid: 16.40% Test: 19.00%
# Epoch: 76, Loss: 0.1731, Train: 43.57%, Valid: 15.20% Test: 17.60%
# Epoch: 77, Loss: 2.4771, Train: 44.29%, Valid: 14.20% Test: 17.60%
# Epoch: 78, Loss: 0.0156, Train: 45.00%, Valid: 15.60% Test: 17.90%
# Epoch: 79, Loss: 3.8404, Train: 44.29%, Valid: 15.20% Test: 16.80%
# Epoch: 80, Loss: 0.0105, Train: 43.57%, Valid: 14.20% Test: 16.60%
# Epoch: 81, Loss: 2.4383, Train: 42.86%, Valid: 14.00% Test: 17.30%
# Epoch: 82, Loss: 2.7360, Train: 45.00%, Valid: 15.20% Test: 17.60%
# Epoch: 83, Loss: 0.0002, Train: 44.29%, Valid: 15.20% Test: 16.90%
# Epoch: 84, Loss: 0.1013, Train: 42.14%, Valid: 15.60% Test: 17.20%
# Epoch: 85, Loss: 0.0024, Train: 44.29%, Valid: 15.60% Test: 17.30%
# Epoch: 86, Loss: 0.9033, Train: 45.00%, Valid: 16.00% Test: 17.70%
# Epoch: 87, Loss: 0.3267, Train: 45.71%, Valid: 16.20% Test: 17.10%
# Epoch: 88, Loss: 0.9536, Train: 46.43%, Valid: 15.20% Test: 17.90%
# Epoch: 89, Loss: 1.2341, Train: 49.29%, Valid: 15.80% Test: 17.70%
# Epoch: 90, Loss: 0.4296, Train: 45.71%, Valid: 15.80% Test: 17.40%
# Epoch: 91, Loss: 0.7260, Train: 45.00%, Valid: 16.40% Test: 17.40%
# Epoch: 92, Loss: 0.2486, Train: 46.43%, Valid: 16.40% Test: 17.50%
# Epoch: 93, Loss: 0.6930, Train: 45.71%, Valid: 16.40% Test: 16.90%
# Epoch: 94, Loss: 2.9394, Train: 47.86%, Valid: 16.00% Test: 16.10%
# Epoch: 95, Loss: 1.6245, Train: 49.29%, Valid: 15.20% Test: 15.50%
# Epoch: 96, Loss: 0.9540, Train: 51.43%, Valid: 16.20% Test: 16.60%
# Epoch: 97, Loss: 0.0336, Train: 50.71%, Valid: 15.60% Test: 16.40%
# Epoch: 98, Loss: 4.6714, Train: 50.71%, Valid: 17.40% Test: 16.40%
# Epoch: 99, Loss: 4.7176, Train: 52.86%, Valid: 16.40% Test: 17.10%
# Epoch: 100, Loss: 2.1094, Train: 54.29%, Valid: 17.40% Test: 17.50%
# Epoch: 101, Loss: 2.6531, Train: 55.71%, Valid: 17.60% Test: 17.90%
# Epoch: 102, Loss: 1.3552, Train: 56.43%, Valid: 17.20% Test: 18.00%
# Epoch: 103, Loss: 0.6029, Train: 57.86%, Valid: 16.40% Test: 18.80%
# Epoch: 104, Loss: 0.0073, Train: 57.14%, Valid: 16.00% Test: 19.30%
# Epoch: 105, Loss: 1.1346, Train: 56.43%, Valid: 16.60% Test: 18.70%
# Epoch: 106, Loss: 0.0130, Train: 57.14%, Valid: 16.20% Test: 18.40%
# Epoch: 107, Loss: 0.0812, Train: 57.14%, Valid: 16.20% Test: 17.70%
# Epoch: 108, Loss: 2.4847, Train: 57.14%, Valid: 16.20% Test: 17.70%
# Epoch: 109, Loss: 0.3421, Train: 60.71%, Valid: 17.00% Test: 18.90%
# Epoch: 110, Loss: 0.3881, Train: 59.29%, Valid: 17.00% Test: 19.90%
# Epoch: 111, Loss: 0.0006, Train: 60.00%, Valid: 16.40% Test: 19.50%
# Epoch: 112, Loss: 3.1432, Train: 60.00%, Valid: 16.40% Test: 19.80%
# Epoch: 113, Loss: 0.1738, Train: 60.00%, Valid: 16.40% Test: 19.70%
# Epoch: 114, Loss: 1.5374, Train: 60.71%, Valid: 16.40% Test: 19.70%
# Epoch: 115, Loss: 2.0604, Train: 59.29%, Valid: 16.60% Test: 19.00%
# Epoch: 116, Loss: 0.9403, Train: 60.71%, Valid: 16.20% Test: 17.20%
# Epoch: 117, Loss: 0.1554, Train: 58.57%, Valid: 17.60% Test: 17.30%
# Epoch: 118, Loss: 0.7807, Train: 59.29%, Valid: 18.00% Test: 16.50%
# Epoch: 119, Loss: 2.1930, Train: 60.71%, Valid: 17.40% Test: 17.00%
# Epoch: 120, Loss: 1.2339, Train: 59.29%, Valid: 17.20% Test: 17.80%
# Epoch: 121, Loss: 1.3981, Train: 57.86%, Valid: 17.00% Test: 17.90%
# Epoch: 122, Loss: 1.3949, Train: 57.86%, Valid: 16.00% Test: 18.00%
# Epoch: 123, Loss: 1.4971, Train: 57.86%, Valid: 17.20% Test: 18.00%
# Epoch: 124, Loss: 1.2161, Train: 60.00%, Valid: 18.20% Test: 18.80%
# Epoch: 125, Loss: 0.1592, Train: 59.29%, Valid: 18.60% Test: 17.80%
# Epoch: 126, Loss: 1.7721, Train: 60.71%, Valid: 17.60% Test: 18.00%
# Epoch: 127, Loss: 0.0668, Train: 62.86%, Valid: 18.20% Test: 18.20%
# Epoch: 128, Loss: 3.0942, Train: 62.86%, Valid: 18.40% Test: 18.60%
# Epoch: 129, Loss: 2.7719, Train: 65.00%, Valid: 18.20% Test: 19.20%
# Epoch: 130, Loss: 0.4081, Train: 64.29%, Valid: 19.40% Test: 21.80%
# Epoch: 131, Loss: 0.2760, Train: 64.29%, Valid: 18.60% Test: 22.70%
# Epoch: 132, Loss: 0.3976, Train: 63.57%, Valid: 19.00% Test: 21.80%
# Epoch: 133, Loss: 0.7913, Train: 62.86%, Valid: 18.40% Test: 21.80%
# Epoch: 134, Loss: 0.0439, Train: 63.57%, Valid: 21.00% Test: 23.40%
# Epoch: 135, Loss: 0.0004, Train: 63.57%, Valid: 22.00% Test: 23.80%
# Epoch: 136, Loss: 4.2310, Train: 62.86%, Valid: 21.40% Test: 24.20%
# Epoch: 137, Loss: 2.5373, Train: 64.29%, Valid: 22.40% Test: 24.80%
# Epoch: 138, Loss: 0.0861, Train: 64.29%, Valid: 21.60% Test: 23.70%
# Epoch: 139, Loss: 0.0095, Train: 62.14%, Valid: 21.80% Test: 23.90%
# Epoch: 140, Loss: 0.9468, Train: 66.43%, Valid: 24.40% Test: 24.90%
# Epoch: 141, Loss: 0.0226, Train: 65.00%, Valid: 24.40% Test: 25.20%
# Epoch: 142, Loss: 1.4802, Train: 65.71%, Valid: 24.20% Test: 25.00%
# Epoch: 143, Loss: 0.3587, Train: 66.43%, Valid: 24.40% Test: 25.00%
# Epoch: 144, Loss: 0.2322, Train: 65.71%, Valid: 24.60% Test: 25.80%
# Epoch: 145, Loss: 3.3827, Train: 66.43%, Valid: 24.80% Test: 26.00%
# Epoch: 146, Loss: 0.2856, Train: 66.43%, Valid: 24.00% Test: 24.10%
# Epoch: 147, Loss: 0.8148, Train: 65.71%, Valid: 24.60% Test: 24.60%
# Epoch: 148, Loss: 0.1549, Train: 67.14%, Valid: 26.20% Test: 24.80%
# Epoch: 149, Loss: 0.2046, Train: 66.43%, Valid: 25.20% Test: 24.20%
# Epoch: 150, Loss: 0.0142, Train: 65.71%, Valid: 25.80% Test: 24.00%
# Saving Model Predictions for Model: cluster louvain
# Best model: Train: 67.14%, Valid: 26.20% Test: 24.80%

# %% [markdown]
# ## **Question 2.2a:** How does the Bisection algorithm partition our graph? (3 points)

# %%
if 'IS_GRADESCOPE_ENV' not in os.environ:
  
  set_seed()

  graphs_train, graphs_val, graphs_test = \
      GraphDataset.pyg_to_graphs(pyg_dataset, verbose=True, fixed_split=True)

  graph_train = graphs_train[0]
  graph_val = graphs_val[0]
  graph_test = graphs_test[0]
  graphs = preprocess(graph_train.G, graph_train.node_label_index, method="bisection")
  print("Partition the graph in to {} communities".format(len(graphs)))
  avg_num_nodes = 0
  avg_num_edges = 0
  for graph in graphs:
      avg_num_nodes += graph.num_nodes
      avg_num_edges += graph.num_edges
  avg_num_nodes = int(avg_num_nodes / len(graphs))
  avg_num_edges = int(avg_num_edges / len(graphs))
  print("Each community has {} nodes in average".format(avg_num_nodes))
  print("Each community has {} edges in average".format(avg_num_edges))
# Out:
# Index fields: train_mask ignored.
# Index fields: test_mask ignored.
# Index fields: val_mask ignored.
# Partition the graph in to 2 communities
# Each community has 1354 nodes in average
# Each community has 2397 edges in average

# %% [markdown]
# ## **Question 2.2b:** Using the Bisection algorithm to partition the graph, what is the maximum test accuracy obtained by your vanilla Cluster-GCN? (6 points)

# %%
if 'IS_GRADESCOPE_ENV' not in os.environ:
  
  set_seed()
  
  model = GNN(graph_train.num_node_features, args['hidden_size'], graph_train.num_node_labels, args).to(args['device'])
  optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'])
  bisection_best_model, bisection_accs = train(graphs, [graph_train, graph_val, graph_test], args, model, optimizer, mode="community")
  train_acc, val_acc, test_acc = test([graph_train, graph_val, graph_test], bisection_best_model, save_model_results=True, batch_type="cluster", title="bisection")
  print('Best model:',
        f'Train: {100 * train_acc:.2f}%, '
        f'Valid: {100 * val_acc:.2f}% '
        f'Test: {100 * test_acc:.2f}%')
# Out:
# Epoch: 01, Loss: 2.1193, Train: 25.71%, Valid: 8.20% Test: 10.20%
# Epoch: 02, Loss: 1.0584, Train: 36.43%, Valid: 12.40% Test: 15.90%
# Epoch: 03, Loss: 2.0182, Train: 53.57%, Valid: 25.60% Test: 29.30%
# Epoch: 04, Loss: 0.3854, Train: 78.57%, Valid: 39.20% Test: 41.60%
# Epoch: 05, Loss: 0.2455, Train: 87.14%, Valid: 51.60% Test: 53.50%
# Epoch: 06, Loss: 0.1568, Train: 91.43%, Valid: 57.60% Test: 59.70%
# Epoch: 07, Loss: 0.6597, Train: 96.43%, Valid: 63.60% Test: 63.50%
# Epoch: 08, Loss: 0.0463, Train: 97.86%, Valid: 66.40% Test: 66.60%
# Epoch: 09, Loss: 0.0458, Train: 98.57%, Valid: 67.80% Test: 68.10%
# Epoch: 10, Loss: 0.3323, Train: 99.29%, Valid: 69.20% Test: 69.70%
# Epoch: 11, Loss: 0.1825, Train: 100.00%, Valid: 69.80% Test: 69.90%
# Epoch: 12, Loss: 0.0131, Train: 100.00%, Valid: 70.20% Test: 70.90%
# Epoch: 13, Loss: 0.0083, Train: 100.00%, Valid: 71.40% Test: 71.30%
# Epoch: 14, Loss: 0.0103, Train: 100.00%, Valid: 71.20% Test: 71.50%
# Epoch: 15, Loss: 0.0158, Train: 100.00%, Valid: 71.20% Test: 71.80%
# Epoch: 16, Loss: 0.0226, Train: 100.00%, Valid: 71.80% Test: 71.90%
# Epoch: 17, Loss: 0.0022, Train: 100.00%, Valid: 72.20% Test: 72.10%
# Epoch: 18, Loss: 0.0181, Train: 100.00%, Valid: 72.20% Test: 72.10%
# Epoch: 19, Loss: 0.0147, Train: 100.00%, Valid: 72.00% Test: 72.50%
# Epoch: 20, Loss: 0.0048, Train: 100.00%, Valid: 71.60% Test: 72.50%
# Epoch: 21, Loss: 0.0062, Train: 100.00%, Valid: 71.60% Test: 72.70%
# Epoch: 22, Loss: 0.0034, Train: 100.00%, Valid: 71.80% Test: 72.90%
# Epoch: 23, Loss: 0.0085, Train: 100.00%, Valid: 71.60% Test: 72.70%
# Epoch: 24, Loss: 0.0026, Train: 100.00%, Valid: 71.40% Test: 72.50%
# Epoch: 25, Loss: 0.0025, Train: 100.00%, Valid: 71.40% Test: 72.60%
# Epoch: 26, Loss: 0.0020, Train: 100.00%, Valid: 71.40% Test: 72.50%
# Epoch: 27, Loss: 0.0019, Train: 100.00%, Valid: 71.60% Test: 72.60%
# Epoch: 28, Loss: 0.0047, Train: 100.00%, Valid: 71.80% Test: 72.70%
# Epoch: 29, Loss: 0.0153, Train: 100.00%, Valid: 72.20% Test: 72.50%
# Epoch: 30, Loss: 0.0015, Train: 100.00%, Valid: 72.40% Test: 72.50%
# Epoch: 31, Loss: 0.0006, Train: 100.00%, Valid: 72.80% Test: 72.20%
# Epoch: 32, Loss: 0.0011, Train: 100.00%, Valid: 72.80% Test: 72.70%
# Epoch: 33, Loss: 0.0006, Train: 100.00%, Valid: 72.60% Test: 72.50%
# Epoch: 34, Loss: 0.0012, Train: 100.00%, Valid: 72.80% Test: 72.50%
# Epoch: 35, Loss: 0.0003, Train: 100.00%, Valid: 72.40% Test: 72.60%
# Epoch: 36, Loss: 0.0004, Train: 100.00%, Valid: 72.80% Test: 72.50%
# Epoch: 37, Loss: 0.0005, Train: 100.00%, Valid: 72.80% Test: 72.60%
# Epoch: 38, Loss: 0.0002, Train: 100.00%, Valid: 72.80% Test: 72.70%
# Epoch: 39, Loss: 0.0019, Train: 100.00%, Valid: 72.80% Test: 72.80%
# Epoch: 40, Loss: 0.0025, Train: 100.00%, Valid: 73.00% Test: 72.70%
# Epoch: 41, Loss: 0.0002, Train: 100.00%, Valid: 72.80% Test: 72.90%
# Epoch: 42, Loss: 0.0003, Train: 100.00%, Valid: 73.00% Test: 72.80%
# Epoch: 43, Loss: 0.0012, Train: 100.00%, Valid: 72.80% Test: 73.10%
# Epoch: 44, Loss: 0.0003, Train: 100.00%, Valid: 73.00% Test: 73.00%
# Epoch: 45, Loss: 0.0011, Train: 100.00%, Valid: 73.00% Test: 73.10%
# Epoch: 46, Loss: 0.0020, Train: 100.00%, Valid: 72.80% Test: 72.90%
# Epoch: 47, Loss: 0.0006, Train: 100.00%, Valid: 72.80% Test: 72.90%
# Epoch: 48, Loss: 0.0013, Train: 100.00%, Valid: 72.60% Test: 73.20%
# Epoch: 49, Loss: 0.0004, Train: 100.00%, Valid: 72.80% Test: 73.00%
# Epoch: 50, Loss: 0.0001, Train: 100.00%, Valid: 72.80% Test: 73.10%
# Epoch: 51, Loss: 0.0004, Train: 100.00%, Valid: 72.60% Test: 72.90%
# Epoch: 52, Loss: 0.0008, Train: 100.00%, Valid: 72.60% Test: 73.10%
# Epoch: 53, Loss: 0.0017, Train: 100.00%, Valid: 72.60% Test: 73.40%
# Epoch: 54, Loss: 0.0018, Train: 100.00%, Valid: 72.60% Test: 73.20%
# Epoch: 55, Loss: 0.0003, Train: 100.00%, Valid: 72.20% Test: 73.00%
# Epoch: 56, Loss: 0.0003, Train: 100.00%, Valid: 72.60% Test: 73.20%
# Epoch: 57, Loss: 0.0000, Train: 100.00%, Valid: 72.20% Test: 73.20%
# Epoch: 58, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 73.20%
# Epoch: 59, Loss: 0.0008, Train: 100.00%, Valid: 72.60% Test: 73.20%
# Epoch: 60, Loss: 0.0002, Train: 100.00%, Valid: 72.80% Test: 73.30%
# Epoch: 61, Loss: 0.0003, Train: 100.00%, Valid: 72.80% Test: 73.30%
# Epoch: 62, Loss: 0.0002, Train: 100.00%, Valid: 72.40% Test: 73.40%
# Epoch: 63, Loss: 0.0001, Train: 100.00%, Valid: 72.00% Test: 73.30%
# Epoch: 64, Loss: 0.0002, Train: 100.00%, Valid: 72.00% Test: 73.10%
# Epoch: 65, Loss: 0.0023, Train: 100.00%, Valid: 72.20% Test: 73.40%
# Epoch: 66, Loss: 0.0001, Train: 100.00%, Valid: 72.00% Test: 73.20%
# Epoch: 67, Loss: 0.0005, Train: 100.00%, Valid: 72.40% Test: 73.30%
# Epoch: 68, Loss: 0.0001, Train: 100.00%, Valid: 72.60% Test: 73.50%
# Epoch: 69, Loss: 0.0018, Train: 100.00%, Valid: 72.80% Test: 73.60%
# Epoch: 70, Loss: 0.0003, Train: 100.00%, Valid: 72.80% Test: 73.60%
# Epoch: 71, Loss: 0.0047, Train: 100.00%, Valid: 73.20% Test: 74.00%
# Epoch: 72, Loss: 0.0000, Train: 100.00%, Valid: 73.20% Test: 73.80%
# Epoch: 73, Loss: 0.0002, Train: 100.00%, Valid: 73.00% Test: 73.90%
# Epoch: 74, Loss: 0.0093, Train: 100.00%, Valid: 73.00% Test: 73.80%
# Epoch: 75, Loss: 0.0007, Train: 100.00%, Valid: 73.40% Test: 74.00%
# Epoch: 76, Loss: 0.0001, Train: 100.00%, Valid: 73.60% Test: 74.10%
# Epoch: 77, Loss: 0.0004, Train: 100.00%, Valid: 73.00% Test: 73.90%
# Epoch: 78, Loss: 0.0001, Train: 100.00%, Valid: 73.20% Test: 74.10%
# Epoch: 79, Loss: 0.0000, Train: 100.00%, Valid: 72.80% Test: 74.00%
# Epoch: 80, Loss: 0.0003, Train: 100.00%, Valid: 72.60% Test: 74.10%
# Epoch: 81, Loss: 0.0000, Train: 100.00%, Valid: 72.80% Test: 74.20%
# Epoch: 82, Loss: 0.0004, Train: 100.00%, Valid: 72.60% Test: 74.20%
# Epoch: 83, Loss: 0.0008, Train: 100.00%, Valid: 72.80% Test: 74.40%
# Epoch: 84, Loss: 0.0001, Train: 100.00%, Valid: 72.60% Test: 74.40%
# Epoch: 85, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 74.40%
# Epoch: 86, Loss: 0.0002, Train: 100.00%, Valid: 72.40% Test: 74.00%
# Epoch: 87, Loss: 0.0001, Train: 100.00%, Valid: 72.40% Test: 74.10%
# Epoch: 88, Loss: 0.0011, Train: 100.00%, Valid: 72.80% Test: 74.50%
# Epoch: 89, Loss: 0.0002, Train: 100.00%, Valid: 72.80% Test: 74.80%
# Epoch: 90, Loss: 0.0002, Train: 100.00%, Valid: 72.80% Test: 75.00%
# Epoch: 91, Loss: 0.0002, Train: 100.00%, Valid: 73.00% Test: 75.00%
# Epoch: 92, Loss: 0.0001, Train: 100.00%, Valid: 73.40% Test: 75.00%
# Epoch: 93, Loss: 0.0000, Train: 100.00%, Valid: 72.80% Test: 75.00%
# Epoch: 94, Loss: 0.0002, Train: 100.00%, Valid: 73.20% Test: 75.00%
# Epoch: 95, Loss: 0.0005, Train: 100.00%, Valid: 73.60% Test: 75.10%
# Epoch: 96, Loss: 0.0000, Train: 100.00%, Valid: 73.00% Test: 75.10%
# Epoch: 97, Loss: 0.0000, Train: 100.00%, Valid: 73.40% Test: 75.00%
# Epoch: 98, Loss: 0.0004, Train: 100.00%, Valid: 73.60% Test: 75.00%
# Epoch: 99, Loss: 0.0000, Train: 100.00%, Valid: 73.00% Test: 75.00%
# Epoch: 100, Loss: 0.0002, Train: 100.00%, Valid: 73.60% Test: 74.80%
# Epoch: 101, Loss: 0.0013, Train: 100.00%, Valid: 73.40% Test: 75.10%
# Epoch: 102, Loss: 0.0000, Train: 100.00%, Valid: 73.40% Test: 75.00%
# Epoch: 103, Loss: 0.0002, Train: 100.00%, Valid: 73.40% Test: 75.00%
# Epoch: 104, Loss: 0.0002, Train: 100.00%, Valid: 73.40% Test: 74.90%
# Epoch: 105, Loss: 0.0001, Train: 100.00%, Valid: 73.00% Test: 74.70%
# Epoch: 106, Loss: 0.0000, Train: 100.00%, Valid: 73.20% Test: 74.80%
# Epoch: 107, Loss: 0.0001, Train: 100.00%, Valid: 73.00% Test: 74.80%
# Epoch: 108, Loss: 0.0000, Train: 100.00%, Valid: 73.00% Test: 74.80%
# Epoch: 109, Loss: 0.0015, Train: 100.00%, Valid: 73.00% Test: 74.70%
# Epoch: 110, Loss: 0.0000, Train: 100.00%, Valid: 72.80% Test: 74.80%
# Epoch: 111, Loss: 0.0001, Train: 100.00%, Valid: 73.00% Test: 74.60%
# Epoch: 112, Loss: 0.0003, Train: 100.00%, Valid: 73.20% Test: 74.80%
# Epoch: 113, Loss: 0.0008, Train: 100.00%, Valid: 73.20% Test: 74.80%
# Epoch: 114, Loss: 0.0000, Train: 100.00%, Valid: 73.00% Test: 74.60%
# Epoch: 115, Loss: 0.0000, Train: 100.00%, Valid: 73.00% Test: 74.10%
# Epoch: 116, Loss: 0.0002, Train: 100.00%, Valid: 73.20% Test: 74.40%
# Epoch: 117, Loss: 0.0003, Train: 100.00%, Valid: 73.40% Test: 74.40%
# Epoch: 118, Loss: 0.0001, Train: 100.00%, Valid: 73.20% Test: 74.10%
# Epoch: 119, Loss: 0.0001, Train: 100.00%, Valid: 73.40% Test: 74.00%
# Epoch: 120, Loss: 0.0002, Train: 100.00%, Valid: 73.40% Test: 74.10%
# Epoch: 121, Loss: 0.0000, Train: 100.00%, Valid: 73.20% Test: 74.00%
# Epoch: 122, Loss: 0.0002, Train: 100.00%, Valid: 73.20% Test: 74.00%
# Epoch: 123, Loss: 0.0001, Train: 100.00%, Valid: 73.20% Test: 74.00%
# Epoch: 124, Loss: 0.0000, Train: 100.00%, Valid: 73.20% Test: 74.10%
# Epoch: 125, Loss: 0.0310, Train: 100.00%, Valid: 72.80% Test: 73.80%
# Epoch: 126, Loss: 0.0001, Train: 100.00%, Valid: 72.40% Test: 73.80%
# Epoch: 127, Loss: 0.0007, Train: 100.00%, Valid: 72.20% Test: 73.60%
# Epoch: 128, Loss: 0.0001, Train: 100.00%, Valid: 72.40% Test: 73.20%
# Epoch: 129, Loss: 0.0000, Train: 100.00%, Valid: 72.00% Test: 72.90%
# Epoch: 130, Loss: 0.0003, Train: 100.00%, Valid: 72.00% Test: 73.00%
# Epoch: 131, Loss: 0.0007, Train: 100.00%, Valid: 71.80% Test: 72.90%
# Epoch: 132, Loss: 0.0001, Train: 100.00%, Valid: 71.80% Test: 72.90%
# Epoch: 133, Loss: 0.0001, Train: 100.00%, Valid: 71.80% Test: 72.90%
# Epoch: 134, Loss: 0.0001, Train: 100.00%, Valid: 71.80% Test: 73.00%
# Epoch: 135, Loss: 0.0007, Train: 100.00%, Valid: 71.80% Test: 73.00%
# Epoch: 136, Loss: 0.0001, Train: 100.00%, Valid: 71.80% Test: 73.00%
# Epoch: 137, Loss: 0.0002, Train: 100.00%, Valid: 71.80% Test: 72.90%
# Epoch: 138, Loss: 0.0000, Train: 100.00%, Valid: 72.00% Test: 72.90%
# Epoch: 139, Loss: 0.0001, Train: 100.00%, Valid: 72.00% Test: 72.90%
# Epoch: 140, Loss: 0.0003, Train: 100.00%, Valid: 71.80% Test: 73.00%
# Epoch: 141, Loss: 0.0003, Train: 100.00%, Valid: 72.00% Test: 72.90%
# Epoch: 142, Loss: 0.0002, Train: 100.00%, Valid: 72.00% Test: 72.90%
# Epoch: 143, Loss: 0.0005, Train: 100.00%, Valid: 72.20% Test: 72.80%
# Epoch: 144, Loss: 0.0002, Train: 100.00%, Valid: 72.40% Test: 72.80%
# Epoch: 145, Loss: 0.0001, Train: 100.00%, Valid: 72.20% Test: 72.50%
# Epoch: 146, Loss: 0.0001, Train: 100.00%, Valid: 72.20% Test: 72.70%
# Epoch: 147, Loss: 0.0000, Train: 100.00%, Valid: 72.00% Test: 72.50%
# Epoch: 148, Loss: 0.0001, Train: 100.00%, Valid: 72.00% Test: 72.70%
# Epoch: 149, Loss: 0.0000, Train: 100.00%, Valid: 72.20% Test: 72.80%
# Epoch: 150, Loss: 0.0000, Train: 100.00%, Valid: 72.00% Test: 72.70%
# Saving Model Predictions for Model: cluster bisection
# Best model: Train: 100.00%, Valid: 73.60% Test: 74.10%

# %% [markdown]
# ## **Question 2.3a:** How does Greedy preprocessing partition our graph? (3 points)

# %%
if 'IS_GRADESCOPE_ENV' not in os.environ:
  
  set_seed()

  graphs_train, graphs_val, graphs_test = \
      GraphDataset.pyg_to_graphs(pyg_dataset, verbose=True, fixed_split=True)

  graph_train = graphs_train[0]
  graph_val = graphs_val[0]
  graph_test = graphs_test[0]
  graphs = preprocess(graph_train.G, graph_train.node_label_index, method="greedy")
  print("Partition the graph in to {} communities".format(len(graphs)))
  avg_num_nodes = 0
  avg_num_edges = 0
  for graph in graphs:
      avg_num_nodes += graph.num_nodes
      avg_num_edges += graph.num_edges
  avg_num_nodes = int(avg_num_nodes / len(graphs))
  avg_num_edges = int(avg_num_edges / len(graphs))
  print("Each community has {} nodes in average".format(avg_num_nodes))
  print("Each community has {} edges in average".format(avg_num_edges))
# Out:
# Index fields: train_mask ignored.
# Index fields: test_mask ignored.
# Index fields: val_mask ignored.
# Partition the graph in to 73 communities
# Each community has 22 nodes in average
# Each community has 32 edges in average

# %% [markdown]
# ## **Question 2.3b:** Using Greedy preprocessing to partition the graph, what is the maximum test accuracy obtained by your vanilla Cluster-GCN? (6 points)

# %%
if 'IS_GRADESCOPE_ENV' not in os.environ: 
  
  set_seed()

  model = GNN(graph_train.num_node_features, args['hidden_size'], graph_train.num_node_labels, args).to(args['device'])
  optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'])
  greedy_best_model, greedy_accs = train(graphs, [graph_train, graph_val, graph_test], args, model, optimizer, mode="community")
  train_acc, val_acc, test_acc = test([graph_train, graph_val, graph_test], greedy_best_model, save_model_results=True, batch_type="cluster", title="greedy")
  print('Best model:',
        f'Train: {100 * train_acc:.2f}%, '
        f'Valid: {100 * val_acc:.2f}% '
        f'Test: {100 * test_acc:.2f}%')
# Out:
# Epoch: 01, Loss: 1.8751, Train: 15.00%, Valid: 7.80% Test: 9.20%
# Epoch: 02, Loss: 2.0714, Train: 16.43%, Valid: 14.20% Test: 16.50%
# Epoch: 03, Loss: 1.6041, Train: 15.00%, Valid: 27.00% Test: 28.70%
# Epoch: 04, Loss: 1.5993, Train: 15.71%, Valid: 30.40% Test: 31.00%
# Epoch: 05, Loss: 2.5023, Train: 15.00%, Valid: 31.20% Test: 31.60%
# Epoch: 06, Loss: 1.6597, Train: 15.00%, Valid: 31.60% Test: 31.90%
# Epoch: 07, Loss: 3.1142, Train: 15.00%, Valid: 31.60% Test: 31.90%
# Epoch: 08, Loss: 2.1303, Train: 15.00%, Valid: 31.60% Test: 31.90%
# Epoch: 09, Loss: 2.1042, Train: 15.00%, Valid: 31.60% Test: 31.90%
# Epoch: 10, Loss: 3.3736, Train: 15.71%, Valid: 31.60% Test: 31.90%
# Epoch: 11, Loss: 3.0648, Train: 16.43%, Valid: 31.60% Test: 32.00%
# Epoch: 12, Loss: 1.3417, Train: 17.14%, Valid: 31.40% Test: 31.90%
# Epoch: 13, Loss: 3.1358, Train: 18.57%, Valid: 31.00% Test: 31.60%
# Epoch: 14, Loss: 2.2557, Train: 20.00%, Valid: 31.00% Test: 30.80%
# Epoch: 15, Loss: 1.1846, Train: 20.71%, Valid: 29.40% Test: 29.90%
# Epoch: 16, Loss: 2.3870, Train: 22.86%, Valid: 28.40% Test: 27.70%
# Epoch: 17, Loss: 2.3676, Train: 24.29%, Valid: 26.00% Test: 24.30%
# Epoch: 18, Loss: 1.3039, Train: 26.43%, Valid: 25.80% Test: 22.40%
# Epoch: 19, Loss: 2.0781, Train: 27.86%, Valid: 25.20% Test: 20.50%
# Epoch: 20, Loss: 0.0794, Train: 24.29%, Valid: 23.00% Test: 18.90%
# Epoch: 21, Loss: 0.5341, Train: 22.86%, Valid: 22.60% Test: 19.10%
# Epoch: 22, Loss: 1.5946, Train: 22.86%, Valid: 21.60% Test: 18.20%
# Epoch: 23, Loss: 0.5472, Train: 22.14%, Valid: 20.40% Test: 18.00%
# Epoch: 24, Loss: 2.3653, Train: 22.14%, Valid: 20.40% Test: 17.60%
# Epoch: 25, Loss: 2.7730, Train: 21.43%, Valid: 19.00% Test: 16.30%
# Epoch: 26, Loss: 1.1143, Train: 23.57%, Valid: 20.00% Test: 16.90%
# Epoch: 27, Loss: 3.2613, Train: 22.14%, Valid: 19.40% Test: 16.80%
# Epoch: 28, Loss: 0.0309, Train: 25.00%, Valid: 19.80% Test: 17.10%
# Epoch: 29, Loss: 1.0033, Train: 27.14%, Valid: 19.60% Test: 17.90%
# Epoch: 30, Loss: 1.3922, Train: 27.14%, Valid: 19.00% Test: 17.30%
# Epoch: 31, Loss: 2.2841, Train: 26.43%, Valid: 18.80% Test: 17.50%
# Epoch: 32, Loss: 2.2999, Train: 29.29%, Valid: 19.20% Test: 18.00%
# Epoch: 33, Loss: 0.2520, Train: 29.29%, Valid: 18.60% Test: 18.10%
# Epoch: 34, Loss: 2.5221, Train: 27.86%, Valid: 19.40% Test: 18.20%
# Epoch: 35, Loss: 2.7221, Train: 29.29%, Valid: 20.20% Test: 17.80%
# Epoch: 36, Loss: 1.1368, Train: 30.71%, Valid: 19.80% Test: 16.70%
# Epoch: 37, Loss: 2.1427, Train: 32.14%, Valid: 20.60% Test: 15.40%
# Epoch: 38, Loss: 0.6633, Train: 32.86%, Valid: 19.00% Test: 15.20%
# Epoch: 39, Loss: 0.7072, Train: 33.57%, Valid: 19.00% Test: 14.70%
# Epoch: 40, Loss: 0.3468, Train: 34.29%, Valid: 19.40% Test: 15.50%
# Epoch: 41, Loss: 2.7416, Train: 35.71%, Valid: 19.80% Test: 15.10%
# Epoch: 42, Loss: 2.2695, Train: 35.00%, Valid: 19.40% Test: 14.70%
# Epoch: 43, Loss: 2.9790, Train: 35.71%, Valid: 18.20% Test: 13.50%
# Epoch: 44, Loss: 1.6740, Train: 38.57%, Valid: 18.20% Test: 13.00%
# Epoch: 45, Loss: 0.0867, Train: 37.86%, Valid: 14.20% Test: 9.80%
# Epoch: 46, Loss: 2.1720, Train: 38.57%, Valid: 14.00% Test: 9.90%
# Epoch: 47, Loss: 2.8636, Train: 41.43%, Valid: 14.20% Test: 9.70%
# Epoch: 48, Loss: 1.3619, Train: 44.29%, Valid: 14.00% Test: 9.80%
# Epoch: 49, Loss: 0.1207, Train: 43.57%, Valid: 12.60% Test: 9.20%
# Epoch: 50, Loss: 1.1152, Train: 43.57%, Valid: 11.80% Test: 8.00%
# Epoch: 51, Loss: 0.5674, Train: 42.86%, Valid: 12.00% Test: 8.30%
# Epoch: 52, Loss: 1.2291, Train: 45.00%, Valid: 11.80% Test: 8.70%
# Epoch: 53, Loss: 0.3197, Train: 45.71%, Valid: 11.80% Test: 9.20%
# Epoch: 54, Loss: 0.8603, Train: 41.43%, Valid: 11.80% Test: 9.20%
# Epoch: 55, Loss: 1.4250, Train: 41.43%, Valid: 9.60% Test: 8.30%
# Epoch: 56, Loss: 0.9844, Train: 42.86%, Valid: 10.80% Test: 8.90%
# Epoch: 57, Loss: 0.7613, Train: 46.43%, Valid: 12.00% Test: 10.00%
# Epoch: 58, Loss: 1.2026, Train: 47.86%, Valid: 12.60% Test: 10.80%
# Epoch: 59, Loss: 4.3580, Train: 47.14%, Valid: 12.80% Test: 11.60%
# Epoch: 60, Loss: 0.3129, Train: 45.00%, Valid: 12.40% Test: 12.60%
# Epoch: 61, Loss: 2.4802, Train: 45.71%, Valid: 13.20% Test: 13.10%
# Epoch: 62, Loss: 0.0352, Train: 47.86%, Valid: 14.20% Test: 13.50%
# Epoch: 63, Loss: 0.1817, Train: 47.14%, Valid: 16.40% Test: 14.40%
# Epoch: 64, Loss: 0.2482, Train: 46.43%, Valid: 17.40% Test: 14.70%
# Epoch: 65, Loss: 2.2124, Train: 46.43%, Valid: 17.80% Test: 14.80%
# Epoch: 66, Loss: 0.8961, Train: 45.71%, Valid: 19.40% Test: 16.70%
# Epoch: 67, Loss: 0.1832, Train: 45.71%, Valid: 20.20% Test: 17.30%
# Epoch: 68, Loss: 1.5241, Train: 45.00%, Valid: 20.80% Test: 17.20%
# Epoch: 69, Loss: 4.0656, Train: 46.43%, Valid: 21.60% Test: 19.10%
# Epoch: 70, Loss: 0.3890, Train: 45.00%, Valid: 23.40% Test: 19.70%
# Epoch: 71, Loss: 0.0932, Train: 46.43%, Valid: 23.60% Test: 19.90%
# Epoch: 72, Loss: 0.5694, Train: 47.14%, Valid: 24.40% Test: 19.60%
# Epoch: 73, Loss: 2.3425, Train: 47.86%, Valid: 25.60% Test: 20.50%
# Epoch: 74, Loss: 0.0076, Train: 48.57%, Valid: 24.20% Test: 20.80%
# Epoch: 75, Loss: 0.8417, Train: 46.43%, Valid: 24.00% Test: 20.20%
# Epoch: 76, Loss: 1.3009, Train: 45.71%, Valid: 23.80% Test: 19.60%
# Epoch: 77, Loss: 0.9563, Train: 47.86%, Valid: 23.60% Test: 18.50%
# Epoch: 78, Loss: 0.0173, Train: 48.57%, Valid: 22.80% Test: 18.50%
# Epoch: 79, Loss: 0.8903, Train: 49.29%, Valid: 22.60% Test: 17.90%
# Epoch: 80, Loss: 2.2571, Train: 47.86%, Valid: 24.00% Test: 19.80%
# Epoch: 81, Loss: 0.9486, Train: 45.71%, Valid: 24.20% Test: 22.10%
# Epoch: 82, Loss: 1.7203, Train: 45.00%, Valid: 24.40% Test: 23.00%
# Epoch: 83, Loss: 0.7386, Train: 44.29%, Valid: 25.00% Test: 23.10%
# Epoch: 84, Loss: 0.0001, Train: 43.57%, Valid: 26.00% Test: 24.90%
# Epoch: 85, Loss: 1.1118, Train: 43.57%, Valid: 27.20% Test: 25.20%
# Epoch: 86, Loss: 0.0040, Train: 41.43%, Valid: 29.20% Test: 26.00%
# Epoch: 87, Loss: 0.0255, Train: 42.14%, Valid: 29.00% Test: 27.10%
# Epoch: 88, Loss: 1.1780, Train: 42.86%, Valid: 28.40% Test: 27.00%
# Epoch: 89, Loss: 0.0019, Train: 44.29%, Valid: 28.00% Test: 26.70%
# Epoch: 90, Loss: 0.0125, Train: 43.57%, Valid: 26.80% Test: 25.40%
# Epoch: 91, Loss: 3.7924, Train: 45.00%, Valid: 26.60% Test: 25.30%
# Epoch: 92, Loss: 2.6481, Train: 46.43%, Valid: 25.80% Test: 25.40%
# Epoch: 93, Loss: 2.9203, Train: 46.43%, Valid: 25.20% Test: 24.30%
# Epoch: 94, Loss: 1.1541, Train: 47.14%, Valid: 24.20% Test: 23.10%
# Epoch: 95, Loss: 2.7262, Train: 47.86%, Valid: 22.20% Test: 22.10%
# Epoch: 96, Loss: 2.7799, Train: 49.29%, Valid: 20.60% Test: 21.00%
# Epoch: 97, Loss: 1.3790, Train: 52.86%, Valid: 18.80% Test: 19.50%
# Epoch: 98, Loss: 3.0441, Train: 52.86%, Valid: 18.60% Test: 16.90%
# Epoch: 99, Loss: 0.2064, Train: 53.57%, Valid: 19.40% Test: 17.50%
# Epoch: 100, Loss: 1.4268, Train: 54.29%, Valid: 18.40% Test: 16.80%
# Epoch: 101, Loss: 0.4051, Train: 52.86%, Valid: 19.40% Test: 16.80%
# Epoch: 102, Loss: 0.0246, Train: 53.57%, Valid: 20.00% Test: 17.00%
# Epoch: 103, Loss: 0.0011, Train: 52.86%, Valid: 19.60% Test: 17.10%
# Epoch: 104, Loss: 0.4157, Train: 52.14%, Valid: 20.00% Test: 19.70%
# Epoch: 105, Loss: 0.7438, Train: 53.57%, Valid: 19.80% Test: 18.80%
# Epoch: 106, Loss: 1.2955, Train: 53.57%, Valid: 20.00% Test: 19.60%
# Epoch: 107, Loss: 0.2118, Train: 55.71%, Valid: 20.00% Test: 18.90%
# Epoch: 108, Loss: 0.0505, Train: 53.57%, Valid: 19.00% Test: 17.20%
# Epoch: 109, Loss: 2.6105, Train: 54.29%, Valid: 19.80% Test: 16.60%
# Epoch: 110, Loss: 0.6746, Train: 55.00%, Valid: 19.40% Test: 17.50%
# Epoch: 111, Loss: 1.3426, Train: 55.00%, Valid: 18.20% Test: 16.30%
# Epoch: 112, Loss: 3.2457, Train: 52.86%, Valid: 16.80% Test: 15.40%
# Epoch: 113, Loss: 0.5739, Train: 51.43%, Valid: 15.60% Test: 15.20%
# Epoch: 114, Loss: 0.3297, Train: 52.14%, Valid: 15.00% Test: 15.60%
# Epoch: 115, Loss: 2.3393, Train: 55.00%, Valid: 15.20% Test: 16.70%
# Epoch: 116, Loss: 0.1086, Train: 56.43%, Valid: 15.40% Test: 16.50%
# Epoch: 117, Loss: 0.1491, Train: 55.71%, Valid: 16.60% Test: 16.80%
# Epoch: 118, Loss: 0.6378, Train: 55.71%, Valid: 16.20% Test: 16.60%
# Epoch: 119, Loss: 4.2811, Train: 55.71%, Valid: 17.20% Test: 17.20%
# Epoch: 120, Loss: 0.1828, Train: 56.43%, Valid: 18.60% Test: 17.90%
# Epoch: 121, Loss: 0.1117, Train: 53.57%, Valid: 18.60% Test: 18.00%
# Epoch: 122, Loss: 0.0151, Train: 53.57%, Valid: 19.40% Test: 18.30%
# Epoch: 123, Loss: 0.1585, Train: 55.00%, Valid: 20.40% Test: 19.20%
# Epoch: 124, Loss: 2.4230, Train: 55.00%, Valid: 19.80% Test: 19.10%
# Epoch: 125, Loss: 3.1923, Train: 55.00%, Valid: 18.60% Test: 19.40%
# Epoch: 126, Loss: 0.0210, Train: 54.29%, Valid: 19.20% Test: 19.60%
# Epoch: 127, Loss: 0.2703, Train: 55.71%, Valid: 19.20% Test: 20.30%
# Epoch: 128, Loss: 0.0638, Train: 55.71%, Valid: 20.00% Test: 20.20%
# Epoch: 129, Loss: 0.7197, Train: 55.00%, Valid: 20.40% Test: 21.40%
# Epoch: 130, Loss: 0.0189, Train: 55.00%, Valid: 21.20% Test: 22.40%
# Epoch: 131, Loss: 1.3136, Train: 55.00%, Valid: 21.60% Test: 22.70%
# Epoch: 132, Loss: 2.7241, Train: 56.43%, Valid: 21.40% Test: 23.40%
# Epoch: 133, Loss: 0.5759, Train: 57.14%, Valid: 21.20% Test: 23.50%
# Epoch: 134, Loss: 0.2435, Train: 55.71%, Valid: 22.20% Test: 23.80%
# Epoch: 135, Loss: 5.7151, Train: 55.71%, Valid: 21.80% Test: 24.20%
# Epoch: 136, Loss: 0.0165, Train: 55.71%, Valid: 20.40% Test: 22.90%
# Epoch: 137, Loss: 0.4344, Train: 57.14%, Valid: 20.00% Test: 22.50%
# Epoch: 138, Loss: 0.9389, Train: 56.43%, Valid: 20.20% Test: 23.00%
# Epoch: 139, Loss: 0.0117, Train: 56.43%, Valid: 19.60% Test: 22.90%
# Epoch: 140, Loss: 4.9129, Train: 57.14%, Valid: 20.60% Test: 22.90%
# Epoch: 141, Loss: 0.6584, Train: 55.71%, Valid: 20.20% Test: 21.60%
# Epoch: 142, Loss: 0.0924, Train: 55.00%, Valid: 20.60% Test: 21.30%
# Epoch: 143, Loss: 0.4246, Train: 55.00%, Valid: 21.00% Test: 21.20%
# Epoch: 144, Loss: 0.0124, Train: 55.71%, Valid: 21.20% Test: 21.90%
# Epoch: 145, Loss: 0.7982, Train: 56.43%, Valid: 21.00% Test: 22.70%
# Epoch: 146, Loss: 0.5645, Train: 55.71%, Valid: 21.00% Test: 22.30%
# Epoch: 147, Loss: 0.0139, Train: 55.71%, Valid: 20.80% Test: 23.40%
# Epoch: 148, Loss: 3.4945, Train: 55.00%, Valid: 20.60% Test: 21.90%
# Epoch: 149, Loss: 1.0232, Train: 55.00%, Valid: 20.20% Test: 22.70%
# Epoch: 150, Loss: 1.1759, Train: 55.00%, Valid: 19.40% Test: 22.70%
# Saving Model Predictions for Model: cluster greedy
# Best model: Train: 15.00%, Valid: 31.60% Test: 31.90%

# %% [markdown]
# ## Full-Batch Training

# %%
if 'IS_GRADESCOPE_ENV' not in os.environ:
  
  set_seed()

  graphs_train, graphs_val, graphs_test = \
      GraphDataset.pyg_to_graphs(pyg_dataset, verbose=True, fixed_split=True)

  graph_train = graphs_train[0]
  graph_val = graphs_val[0]
  graph_test = graphs_test[0]

  model = GNN(graph_train.num_node_features, args['hidden_size'], graph_train.num_node_labels, args).to(args['device'])
  optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'])
  graphs = [graph_train, graph_val, graph_test]
  all_best_model, all_accs = train(graphs, graphs, args, model, optimizer, mode="all")
  train_acc, val_acc, test_acc = test([graph_train, graph_val, graph_test], all_best_model)
  print('Best model:',
        f'Train: {100 * train_acc:.2f}%, '
        f'Valid: {100 * val_acc:.2f}% '
        f'Test: {100 * test_acc:.2f}%')
# Out:
# Index fields: train_mask ignored.
# Index fields: test_mask ignored.
# Index fields: val_mask ignored.
# Epoch: 01, Loss: 2.0228, Train: 65.00%, Valid: 29.20% Test: 35.00%
# Epoch: 02, Loss: 1.0957, Train: 98.57%, Valid: 54.40% Test: 58.40%
# Epoch: 03, Loss: 0.6141, Train: 100.00%, Valid: 68.80% Test: 69.80%
# Epoch: 04, Loss: 0.2814, Train: 100.00%, Valid: 74.00% Test: 73.80%
# Epoch: 05, Loss: 0.1553, Train: 100.00%, Valid: 75.60% Test: 75.60%
# Epoch: 06, Loss: 0.0629, Train: 100.00%, Valid: 76.40% Test: 76.10%
# Epoch: 07, Loss: 0.0454, Train: 100.00%, Valid: 76.60% Test: 76.00%
# Epoch: 08, Loss: 0.0232, Train: 100.00%, Valid: 77.20% Test: 76.40%
# Epoch: 09, Loss: 0.0108, Train: 100.00%, Valid: 76.80% Test: 76.20%
# Epoch: 10, Loss: 0.0120, Train: 100.00%, Valid: 77.20% Test: 75.90%
# Epoch: 11, Loss: 0.0047, Train: 100.00%, Valid: 76.80% Test: 76.00%
# Epoch: 12, Loss: 0.0061, Train: 100.00%, Valid: 76.60% Test: 76.10%
# Epoch: 13, Loss: 0.0046, Train: 100.00%, Valid: 76.20% Test: 75.90%
# Epoch: 14, Loss: 0.0012, Train: 100.00%, Valid: 76.00% Test: 75.90%
# Epoch: 15, Loss: 0.0049, Train: 100.00%, Valid: 75.80% Test: 75.90%
# Epoch: 16, Loss: 0.0019, Train: 100.00%, Valid: 75.40% Test: 75.70%
# Epoch: 17, Loss: 0.0006, Train: 100.00%, Valid: 75.20% Test: 75.70%
# Epoch: 18, Loss: 0.0013, Train: 100.00%, Valid: 75.20% Test: 75.60%
# Epoch: 19, Loss: 0.0003, Train: 100.00%, Valid: 75.00% Test: 75.70%
# Epoch: 20, Loss: 0.0005, Train: 100.00%, Valid: 75.00% Test: 75.60%
# Epoch: 21, Loss: 0.0003, Train: 100.00%, Valid: 75.20% Test: 75.70%
# Epoch: 22, Loss: 0.0001, Train: 100.00%, Valid: 75.20% Test: 75.40%
# Epoch: 23, Loss: 0.0005, Train: 100.00%, Valid: 75.00% Test: 75.30%
# Epoch: 24, Loss: 0.0004, Train: 100.00%, Valid: 74.60% Test: 75.20%
# Epoch: 25, Loss: 0.0001, Train: 100.00%, Valid: 74.80% Test: 75.10%
# Epoch: 26, Loss: 0.0002, Train: 100.00%, Valid: 74.60% Test: 75.10%
# Epoch: 27, Loss: 0.0005, Train: 100.00%, Valid: 74.60% Test: 75.10%
# Epoch: 28, Loss: 0.0002, Train: 100.00%, Valid: 74.80% Test: 75.10%
# Epoch: 29, Loss: 0.0007, Train: 100.00%, Valid: 74.80% Test: 75.10%
# Epoch: 30, Loss: 0.0001, Train: 100.00%, Valid: 74.80% Test: 75.20%
# Epoch: 31, Loss: 0.0007, Train: 100.00%, Valid: 74.80% Test: 75.10%
# Epoch: 32, Loss: 0.0000, Train: 100.00%, Valid: 75.00% Test: 75.00%
# Epoch: 33, Loss: 0.0001, Train: 100.00%, Valid: 75.00% Test: 75.10%
# Epoch: 34, Loss: 0.0000, Train: 100.00%, Valid: 75.00% Test: 75.20%
# Epoch: 35, Loss: 0.0001, Train: 100.00%, Valid: 75.00% Test: 75.20%
# Epoch: 36, Loss: 0.0000, Train: 100.00%, Valid: 74.80% Test: 75.30%
# Epoch: 37, Loss: 0.0000, Train: 100.00%, Valid: 74.60% Test: 75.40%
# Epoch: 38, Loss: 0.0000, Train: 100.00%, Valid: 74.60% Test: 75.40%
# Epoch: 39, Loss: 0.0001, Train: 100.00%, Valid: 74.60% Test: 75.40%
# Epoch: 40, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 75.40%
# Epoch: 41, Loss: 0.0002, Train: 100.00%, Valid: 74.20% Test: 75.10%
# Epoch: 42, Loss: 0.0002, Train: 100.00%, Valid: 74.40% Test: 74.90%
# Epoch: 43, Loss: 0.0000, Train: 100.00%, Valid: 74.60% Test: 75.00%
# Epoch: 44, Loss: 0.0000, Train: 100.00%, Valid: 74.60% Test: 75.00%
# Epoch: 45, Loss: 0.0001, Train: 100.00%, Valid: 74.60% Test: 74.90%
# Epoch: 46, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 74.80%
# Epoch: 47, Loss: 0.0001, Train: 100.00%, Valid: 74.40% Test: 74.80%
# Epoch: 48, Loss: 0.0007, Train: 100.00%, Valid: 74.40% Test: 74.90%
# Epoch: 49, Loss: 0.0001, Train: 100.00%, Valid: 74.40% Test: 74.80%
# Epoch: 50, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 74.80%
# Epoch: 51, Loss: 0.0001, Train: 100.00%, Valid: 74.40% Test: 74.90%
# Epoch: 52, Loss: 0.0001, Train: 100.00%, Valid: 74.40% Test: 75.00%
# Epoch: 53, Loss: 0.0001, Train: 100.00%, Valid: 74.60% Test: 75.00%
# Epoch: 54, Loss: 0.0001, Train: 100.00%, Valid: 74.60% Test: 74.90%
# Epoch: 55, Loss: 0.0005, Train: 100.00%, Valid: 74.60% Test: 74.90%
# Epoch: 56, Loss: 0.0001, Train: 100.00%, Valid: 74.60% Test: 74.90%
# Epoch: 57, Loss: 0.0001, Train: 100.00%, Valid: 74.60% Test: 74.90%
# Epoch: 58, Loss: 0.0001, Train: 100.00%, Valid: 74.60% Test: 75.00%
# Epoch: 59, Loss: 0.0000, Train: 100.00%, Valid: 74.60% Test: 75.00%
# Epoch: 60, Loss: 0.0001, Train: 100.00%, Valid: 74.60% Test: 75.00%
# Epoch: 61, Loss: 0.0002, Train: 100.00%, Valid: 74.60% Test: 75.00%
# Epoch: 62, Loss: 0.0002, Train: 100.00%, Valid: 74.60% Test: 75.00%
# Epoch: 63, Loss: 0.0000, Train: 100.00%, Valid: 74.60% Test: 75.00%
# Epoch: 64, Loss: 0.0001, Train: 100.00%, Valid: 74.60% Test: 75.00%
# Epoch: 65, Loss: 0.0000, Train: 100.00%, Valid: 74.60% Test: 75.00%
# Epoch: 66, Loss: 0.0000, Train: 100.00%, Valid: 74.60% Test: 74.90%
# Epoch: 67, Loss: 0.0001, Train: 100.00%, Valid: 74.60% Test: 75.00%
# Epoch: 68, Loss: 0.0000, Train: 100.00%, Valid: 74.60% Test: 75.00%
# Epoch: 69, Loss: 0.0000, Train: 100.00%, Valid: 74.60% Test: 75.00%
# Epoch: 70, Loss: 0.0001, Train: 100.00%, Valid: 74.60% Test: 75.10%
# Epoch: 71, Loss: 0.0001, Train: 100.00%, Valid: 74.60% Test: 75.10%
# Epoch: 72, Loss: 0.0001, Train: 100.00%, Valid: 74.80% Test: 75.10%
# Epoch: 73, Loss: 0.0000, Train: 100.00%, Valid: 74.80% Test: 75.10%
# Epoch: 74, Loss: 0.0000, Train: 100.00%, Valid: 74.80% Test: 75.20%
# Epoch: 75, Loss: 0.0001, Train: 100.00%, Valid: 74.80% Test: 75.20%
# Epoch: 76, Loss: 0.0001, Train: 100.00%, Valid: 74.80% Test: 75.20%
# Epoch: 77, Loss: 0.0002, Train: 100.00%, Valid: 74.80% Test: 75.20%
# Epoch: 78, Loss: 0.0001, Train: 100.00%, Valid: 74.80% Test: 75.20%
# Epoch: 79, Loss: 0.0000, Train: 100.00%, Valid: 74.80% Test: 75.20%
# Epoch: 80, Loss: 0.0000, Train: 100.00%, Valid: 74.80% Test: 75.20%
# Epoch: 81, Loss: 0.0000, Train: 100.00%, Valid: 74.80% Test: 75.20%
# Epoch: 82, Loss: 0.0000, Train: 100.00%, Valid: 74.80% Test: 75.20%
# Epoch: 83, Loss: 0.0000, Train: 100.00%, Valid: 74.80% Test: 75.20%
# Epoch: 84, Loss: 0.0000, Train: 100.00%, Valid: 74.80% Test: 75.20%
# Epoch: 85, Loss: 0.0000, Train: 100.00%, Valid: 74.80% Test: 75.20%
# Epoch: 86, Loss: 0.0000, Train: 100.00%, Valid: 75.00% Test: 75.40%
# Epoch: 87, Loss: 0.0001, Train: 100.00%, Valid: 75.00% Test: 75.40%
# Epoch: 88, Loss: 0.0001, Train: 100.00%, Valid: 75.00% Test: 75.60%
# Epoch: 89, Loss: 0.0001, Train: 100.00%, Valid: 74.80% Test: 75.50%
# Epoch: 90, Loss: 0.0000, Train: 100.00%, Valid: 75.00% Test: 75.50%
# Epoch: 91, Loss: 0.0000, Train: 100.00%, Valid: 75.00% Test: 75.50%
# Epoch: 92, Loss: 0.0000, Train: 100.00%, Valid: 75.00% Test: 75.40%
# Epoch: 93, Loss: 0.0000, Train: 100.00%, Valid: 75.00% Test: 75.40%
# Epoch: 94, Loss: 0.0000, Train: 100.00%, Valid: 75.00% Test: 75.40%
# Epoch: 95, Loss: 0.0001, Train: 100.00%, Valid: 75.00% Test: 75.40%
# Epoch: 96, Loss: 0.0005, Train: 100.00%, Valid: 75.00% Test: 75.30%
# Epoch: 97, Loss: 0.0001, Train: 100.00%, Valid: 75.00% Test: 75.10%
# Epoch: 98, Loss: 0.0000, Train: 100.00%, Valid: 75.00% Test: 75.00%
# Epoch: 99, Loss: 0.0000, Train: 100.00%, Valid: 75.00% Test: 75.00%
# Epoch: 100, Loss: 0.0000, Train: 100.00%, Valid: 75.00% Test: 75.00%
# Epoch: 101, Loss: 0.0000, Train: 100.00%, Valid: 75.00% Test: 75.00%
# Epoch: 102, Loss: 0.0000, Train: 100.00%, Valid: 75.00% Test: 75.10%
# Epoch: 103, Loss: 0.0000, Train: 100.00%, Valid: 75.00% Test: 75.10%
# Epoch: 104, Loss: 0.0001, Train: 100.00%, Valid: 74.80% Test: 75.10%
# Epoch: 105, Loss: 0.0000, Train: 100.00%, Valid: 74.80% Test: 75.10%
# Epoch: 106, Loss: 0.0000, Train: 100.00%, Valid: 74.80% Test: 75.20%
# Epoch: 107, Loss: 0.0003, Train: 100.00%, Valid: 74.60% Test: 75.30%
# Epoch: 108, Loss: 0.0000, Train: 100.00%, Valid: 74.60% Test: 75.20%
# Epoch: 109, Loss: 0.0000, Train: 100.00%, Valid: 74.60% Test: 75.20%
# Epoch: 110, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 75.20%
# Epoch: 111, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 75.10%
# Epoch: 112, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 75.10%
# Epoch: 113, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 75.10%
# Epoch: 114, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 75.10%
# Epoch: 115, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 75.10%
# Epoch: 116, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 75.10%
# Epoch: 117, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 75.10%
# Epoch: 118, Loss: 0.0001, Train: 100.00%, Valid: 74.40% Test: 75.10%
# Epoch: 119, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 75.10%
# Epoch: 120, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 75.10%
# Epoch: 121, Loss: 0.0008, Train: 100.00%, Valid: 74.40% Test: 75.10%
# Epoch: 122, Loss: 0.0003, Train: 100.00%, Valid: 74.40% Test: 75.10%
# Epoch: 123, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 75.10%
# Epoch: 124, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 75.20%
# Epoch: 125, Loss: 0.0001, Train: 100.00%, Valid: 74.40% Test: 75.20%
# Epoch: 126, Loss: 0.0002, Train: 100.00%, Valid: 74.40% Test: 75.20%
# Epoch: 127, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 75.20%
# Epoch: 128, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 75.20%
# Epoch: 129, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 75.30%
# Epoch: 130, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 75.30%
# Epoch: 131, Loss: 0.0001, Train: 100.00%, Valid: 74.40% Test: 75.30%
# Epoch: 132, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 75.30%
# Epoch: 133, Loss: 0.0001, Train: 100.00%, Valid: 74.40% Test: 75.40%
# Epoch: 134, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 75.40%
# Epoch: 135, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 75.40%
# Epoch: 136, Loss: 0.0028, Train: 100.00%, Valid: 74.40% Test: 75.30%
# Epoch: 137, Loss: 0.0000, Train: 100.00%, Valid: 74.20% Test: 75.40%
# Epoch: 138, Loss: 0.0000, Train: 100.00%, Valid: 74.20% Test: 75.20%
# Epoch: 139, Loss: 0.0000, Train: 100.00%, Valid: 74.20% Test: 75.20%
# Epoch: 140, Loss: 0.0000, Train: 100.00%, Valid: 74.20% Test: 75.10%
# Epoch: 141, Loss: 0.0000, Train: 100.00%, Valid: 74.20% Test: 75.20%
# Epoch: 142, Loss: 0.0000, Train: 100.00%, Valid: 74.20% Test: 75.10%
# Epoch: 143, Loss: 0.0000, Train: 100.00%, Valid: 74.40% Test: 75.20%
# Epoch: 144, Loss: 0.0000, Train: 100.00%, Valid: 74.20% Test: 75.00%
# Epoch: 145, Loss: 0.0000, Train: 100.00%, Valid: 74.00% Test: 75.00%
# Epoch: 146, Loss: 0.0000, Train: 100.00%, Valid: 74.00% Test: 74.90%
# Epoch: 147, Loss: 0.0000, Train: 100.00%, Valid: 74.00% Test: 74.90%
# Epoch: 148, Loss: 0.0000, Train: 100.00%, Valid: 74.00% Test: 74.90%
# Epoch: 149, Loss: 0.0000, Train: 100.00%, Valid: 74.00% Test: 74.90%
# Epoch: 150, Loss: 0.0000, Train: 100.00%, Valid: 74.00% Test: 74.90%
# Best model: Train: 100.00%, Valid: 77.20% Test: 76.40%

# %% [markdown]
# ## Visualization

# %%
import numpy as np
from matplotlib import pyplot as plt

if 'IS_GRADESCOPE_ENV' not in os.environ:
  louvain_results = np.array(louvain_accs)
  bisection_results = np.array(bisection_accs)
  greedy_results = np.array(greedy_accs)
  all_results = np.array(all_accs)

  x = np.arange(1, 151)

  plt.figure(figsize=(9, 7))

  plt.plot(x, louvain_results[:, 1], label="Louvain Validation")
  plt.plot(x, louvain_results[:, 2], label="Louvain Test")
  plt.plot(x, bisection_results[:, 1], label="Bisection Validation")
  plt.plot(x, bisection_results[:, 2], label="Bisection Test")
  plt.plot(x, greedy_results[:, 1], label="Greedy Validation")
  plt.plot(x, greedy_results[:, 2], label="Greedy Test")
  plt.plot(x, all_results[:, 1], label="All Validation")
  plt.plot(x, all_results[:, 2], label="All Test")
  plt.title('Model Accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

# %% [markdown]
# # Submission
#
# You will need to submit three files on Gradescope to complete this notebook.
#
# 1.   Your completed *XCS224W_Colab5.ipynb*. From the "File" menu select "Download .ipynb" to save a local copy of your completed Colab.
# 2.  *CORA_Node_batch_(0.7,0.9,1).csv*
# 3.  *CORA_Node_batch_(0.3,0.5,1).csv*
# 4.  *CORA_Node_cluster_louvain.csv*
# 5.  *CORA_Node_cluster_greedy.csv*
# 6.  *CORA_Node_cluster_bisection.csv*
#
# Download the csv files by selecting the *Folder* icon on the left panel.
#
# To submit your work, zip the files downloaded in steps 1-7 above and submit to gradescope. **NOTE:** DO NOT rename any of the downloaded files.
